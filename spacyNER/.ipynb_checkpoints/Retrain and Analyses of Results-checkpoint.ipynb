# %%
from __future__ import unicode_literals,print_function

import json
import plac
import random
import spacy
import warnings
from pathlib import Path
from spacy.util import minibatch,compounding
nlp_de1 = spacy.load("de_core_news_sm")
nlp_de2 = spacy.load("de_core_news_md")

# %% [markdown]
# ### Create train data

# %%
with open("novo_train_de.json",'r',encoding="utf-8")as f:
    train_data = json.load(f)
print(train_data[1])
# Out:
# ["Gesetzgeber. Den 19. Niv. (8. Jän.) warddie Staatskleidung der Sekretär-Redacteurs, derStaatsbothen und Thorwächter für beyde Räthebestimmt. Auf Talot's Vorschlag beschloß manüber den constitutionellen Umkreis, welchen dasgesetzgebende Corps in Zukunft inne haben soll, folgendes: Vom Tage an, da der Rath der 500 in seinen neuen Pallast installirt seyn wird, sind dieäußerlichen Bezirke für beyde Räthe folgendermassen firir: Rarh der Alten: Der Umfang des Nationalpallastes der Alten, in den Tuillerien situirt,enhält gegen Westen die Straße und den Platz desCarrousel bis zum Eintritt in die Straße Nicaise,am Hause Coigny vorbey bis zur Straße des Orties, die Passage de Marigny mit einbegriffen: gegen Suden den Theil des Quai der Gallerien desLouvre's von der Passage de Marigny am rechtenUfer der Seine hinab bis zum Quai der Tuilerien,vom rechten Winkel des Parapets bey der Nationalbrucke bis an den Eingang zum Platze de la Coneorde, die Nationalbrücke bis zum Quai Voltairemit einbegriffen; gegen Osten den Platz de la Concorde in Gemeinschaft mit dem Rathe der 500: gegen Norden den Hof der Orangerie, die Passagedes Feuillans, die Casernen der Grenadiers desgesetzg. Corps mit Zubehörden, den jetzigen Saalder 500 nebst den dazu gehörigen Garten und Gebäuden des Feuillans rc. Rath der 500. Der Umkreis des neuen Nationalpallasies der 500, demAntritt der Revolutionsbrücke gegenüber am Seineufer gelegen, enthält gegen Norden den Quaid'Orsai bis zur Nationalbrücke, den Platz delaConcorde bis zur Orangerie, längs der Gebäude duGardemeuble an den elyseischen Feldern hin biszum Anfange der Straße nach Versailles und demdie Esplanade der Invaliden von der Mauer umden Garten des Raths der 500 scheidet, vom Quai d'Orsai bis zur Universitätsgasse: gegen Süden diese Gasse bis zur Straße Courty; gegen Ostendie Straße Bourgogne bis zum Quai d'Orsai Indiesem Bezirke haben die Saalinspectoren die Polizeyaufsicht allein; doch kann die allgemeine PolizeyDee ", ['Talot', 145, 150, 'pers'], ['Rath', 301, 305, 'org'], ['Rarh', 427, 431, 'org'], ['Tuillerien', 494, 504, 'loc'], ['Platz', 552, 557, 'loc'], ['Straße', 595, 601, 'loc'], ['Hause', 613, 618, 'loc'], ['Straße', 641, 647, 'loc'], ['Passage', 664, 671, 'loc'], ['Quai', 727, 731, 'loc'], ['Passage', 766, 773, 'loc'], ['Seine', 804, 809, 'loc'], ['Quai', 824, 828, 'loc'], ['Nationalbrucke', 883, 897, 'loc'], ['Platze', 921, 927, 'loc'], ['Nationalbrücke', 948, 962, 'loc'], ['Quai', 971, 975, 'loc'], ['Platz', 1018, 1023, 'loc'], ['Rathe', 1063, 1068, 'org'], ['Hof', 1095, 1098, 'loc'], ['Passagedes', 1118, 1128, 'loc'], ['Gebäuden', 1263, 1271, 'loc'], ['Rath', 1290, 1294, 'org'], ['Nationalpallasies', 1326, 1343, 'loc'], ['Revolutionsbrücke', 1368, 1385, 'loc'], ['Seineufer', 1399, 1408, 'loc'], ['Quaid', 1443, 1448, 'loc'], ['Nationalbrücke', 1463, 1477, 'loc'], ['Platz', 1483, 1488, 'loc'], ['Orangerie', 1510, 1519, 'loc'], ['Gebäude', 1531, 1538, 'loc'], ['Versailles', 1615, 1625, 'loc'], ['Esplanade', 1637, 1646, 'loc'], ['Raths', 1692, 1697, 'org'], ['Quai', 1720, 1724, 'loc'], ['Universitätsgasse', 1741, 1758, 'loc'], ['Straße', 1792, 1798, 'loc'], ['Straße', 1822, 1828, 'loc'], ['Quai', 1847, 1851, 'loc']]

# %% [markdown]
# A. Z.)Belgien
#
# desneuen
#
# derBompartschen
#
# aufZürich
#
# Institutin Zürich
#
# derSociété
#
# dem
#
# den
#
# laPlata
#
# delas = de las

# %%
l = result2[2]
for x in l:
    print(x[0])
    print(x[4])
    print("----")
    print()
# Out:
# Prinzen
#  kaiserl. Majestät haben dem Prinzen vonCondé bey dessen Ankunft in
# ----
#
# Prinzen
#  Kavallerie-Regimentern bestehende Corps des Prinzen vonCondé, welches in kaiserliche Dienste
# ----
#
# Prinzen
#  wird unterbestandiger Inspection des Prinzen von Condéstehen. Se. kaiserl. Majestät
# ----
#
# Lords
#  Im Oberhause sprachen die Lords Darnleyund Craven dafür, der Marquis
# ----
#
# Craven
#  sprachen die Lords Darnleyund Craven dafür, der Marquis Lansdowne undder
# ----
#
# junge
#  der Marquis Lansdowne undder junge Lord Holland (Neveu von For)
# ----
#
# Nitter
#  Gower die Addressevor, die Nitter Sinclair und Francis Burdett warendie
# ----
#
# For
#  die sich dagegen erheben; For, Sheriban,und die übrigen berühmtesten
# ----
#
# Pitt
#  Ende inbeyden Häusern bewilligt. Pitt sprach diesmal garnicht, sondern kündigte
# ----
#
# Adm
#  votirten beyde HäuserDanksagungen für Adm. Nelson, Commodore Warren,und deren
# ----
#
# NelsonsBelohnung
#  Bothschaft des Königs, über NelsonsBelohnung, das merkwürdigste. Er zeigte
# ----
#
# ben
#  vomNil und Burnharm Torpe vererben soll) eine freyeLeibrente von 2000
# ----
#
# Bompartschen
#  Tone, den man auf derBompartschen Eskader gefangen nahm, ward von
# ----
#
# Abukir
#  —Die von Nelson bey Abukir eroberten Schiffe sind am27. Oct.
# ----
#
# Gibraltar
#  dassouveraine Volk, ist zu Gibraltar geblieben, um alsMagazinschif zu dienen.
# ----
#
# Bengalen
#  zu dienen. — Aus Bengalen ist über Landein Courier angekommen,
# ----
#
# neuen
#  welcher über die Ankunft desneuen Gouverneurs, Lord Mornington, Gewißheit mitbringt.
# ----
#
# Tippo
#  Lord Mornington, Gewißheit mitbringt. Tippo Saib verhielt sich noch ganz
# ----
#
# Wesel
#  in den vereinigten Departements.] Wesel, vom 28. Nov. In
# ----
#
# Aachen
#  die Rebellen in Weerdt; zuAachen haben sie samtliche Einwohner entwaffnet,
# ----
#
# Mosel
#  Alle Schiffe auf der Mosel werden von den Franken in
# ----
#
# Leyden
#  den Franken in Grund gebort.Leyden, vom 30. Nov. Die
# ----
#
# Leydner
#  Stelle des 56. Stk.der Leydner-Zeitung, welche auch ihre Gegend,
# ----
#
# ehemalige
#  Gegend, und überhaupt das ehemalige Herzogthum Lüttich, als in dem
# ----
#
# Löwenunter
#  am 4. Nov. von Löwenunter dem General Jardon abgegangenen Truppen
# ----
#
# Munizipal
#  seiner vornehmsten Häupter, der Munizipal-Agent von Roumiroir, Constant, in
# ----
#
# das
#  600. Gulden Einkommenshat, für das J. 1798, und endlich von
# ----
#
# bis
#  für die folgenden Jahre bis 1824.besteht. Für die ersten (nämlich
# ----
#
# Trochtelfingen
# Mörspurg, 13. May. Zu Trochtelfingen, einemFürstl. Hohenzöllern Sitzmaringischen Städtchen,
# ----
#
# Hohenzöllern
#  May. Zu Trochtelfingen, einemFürstl. Hohenzöllern Sitzmaringischen Städtchen, wurde am jüngsten
# ----
#
# Johannes
#  demZwischenspiel der Enthauptung des Johannes des Taufers, von der dortigen
# ----
#
# Gemeine
#  Grausbackdie Weisung ertheilt: Der Gemeine Trochtelfingen dieBischöfl. Mißbilligung eines Spektakels
# ----
#
# Christenthum
#  sey, wahre Verehrungfür das Christenthum einzuflößen, und die Gemüther zumhohen
# ----
#
# Wiener
# Spanien.In der Wiener-Hofzeitung vom 8. Oct. liest
# ----
#
# General
#  Am 16. Jul. hat derGeneral Reding an der Spitze seiner
# ----
#
# Mengibar
#  allenihren Verschanzungen bey der Mengibar vertrieben; vorzüglich haben dabey die
# ----
#
# Marquis
#  die feindlichen Kürassiers gelitten. DerMarquis Coupigny, der mit mit seiner
# ----
#
# Villanueva
#  angriff, delogirteden Feind aus Villanueva, 200. Franzosen blieben todt,viele
# ----
#
# Coupigny
#  denFlanken von Reding und Coupigny beschäftigte feindlicheHauptmacht. Am 19. Jul.
# ----
#
# Andujar
#  Castanhjos die Nachricht: Düpont habeAndujar geräumt, und ziehe sich eiligst
# ----
#
# Gerona
#  Jul. Der Angriff von Gerona hat den Franzosen über 2000.
# ----
#
# Gerona
#  Tagen sind sieabermal gegen Gerona aufgebrochen, aber bald wieder vondiesem
# ----
#
# Arragonische
#  feindliche Angriff auf die Arragonische Hauptstadt Saragossa, unter dem General
# ----
#
# Saragossa
#  verloren. Von der Unmöglichkeit überzeugt,Saragossa zu bezwingen, retirirten sie nach
# ----
#
# Villa
#  bezwingen, retirirten sie nach Villa-Feliche,vermuthlich, um sich in den
# ----
#
# Obergenerals
#  Truppen, in Gegenwart ihres Obergenerals,Castanhjos, und streckte das Gewehr.
# ----
#
# Generale
#  Jul. haben die Divisionen derGenerale Vedel und Goubot gleichfalls kapitulirt,
# ----
#
# Goubot
#  Divisionen derGenerale Vedel und Goubot gleichfalls kapitulirt, undWaffen und Artillerie
# ----
#
# Düponts
#  Baylen zurückgeblieben, so daß Düponts ganzer Verlust an Todten,Verwundeten und
# ----
#
# Detuwol
#  der wodlgeachte Gemeindratd von Detuwol., Derzirks Mury, Cantons Aargau,
# ----
#
# vorgestellt
#  hiesigen Bezirksgericht mit Mehrerem vorgestellt, daß er zu größerer
# ----
#
# Gemeinden
#  denObern Freyen Aemtern gelegenen Gemeinden Beinwyl,Wiggwyl, Winterschwyl, Brunnwyl, Wallenschwyl oderder
# ----
#
# Summeri
#  Wallenschwyl oderder Höfe Grüt, Summeri, Grod, Brand und Tschöpliverschrieben
# ----
#
# Grod
#  oderder Höfe Grüt, Summeri, Grod, Brand und Tschöpliverschrieben sind,
# ----
#
# Frankteich
# Frankteich.Pariser Korrespondenznachrichten vom 22. Jau.
# ----
#
# Herzogs
#  Blätter liefern folgendes Schreiben desHerzogs von Broglie, Pairs von Frankreich,
# ----
#
# H
#  Schreibens an den MinisterDecazes, H. Chevalier: „Mein Herr, eine
# ----
#
# Bayern
#  Königl. Hoh. der Kronprinz vonBayern sind vorigen Mittwoch von Neapel
# ----
#
# Deutschlandzurückkehren
#  habe, und unverzüglich nach Deutschlandzurückkehren werde. — Ihre Königl. Hoh.
# ----
#
# Wales
#  Königl. Hoh. die Prinzessin v.Wales liegt auf ihrem Landgute bey
# ----
#
# Pesaro
#  auf ihrem Landgute bey Pesaro gefährlichkrank. Der Schmerz über den
# ----
#
# Hannoverschreiten
#  über das Konkordat mit Hannoverschreiten vorwärts; auch zu einem mit
# ----
#
# Deutschland
#  als die kirchlichen Angelegenheiten inDeutschland recht bald und zu gegenseitigem
# ----
#
# Diario
#  kanonischem Wege zu schreiten.Das Diario di Roma meldet unterm 2.
# ----
#
# Hr
#  Kompagnien, welchesseiner Zeit dem Hr. Oberst Salis-Soglio bewilligt ward,
# ----
#
# Wohlen
#  zwey Kompagnien dießJahr nach Wohlen abschicken wolle, wurde nun an
# ----
#
# Wohlen
#  die das Uebungslager zu Wohlen besuchen wollen, so möge es
# ----
#
# Hr
#  es an die Wahlen. Hr. Kantonsstatthalter Dominik Jütz ward
# ----
#
# Hr
#  ward als Landammann, und Hr. Alt-Kantonsseckelmeister Nazar Richlin als
# ----
#
# Hr
#  und auf die Tagsatzung Hr. Landammann Jütz und Hr.Landammann
# ----
#
# geflüchteten
#  Werk des Sohnes jenes geflüchteten Apsilanti war; daß derselbe öffentlich
# ----
#
# Moldau
#  Gebieten Rußlands in die Moldau rückte, an der Spitzeeiner Bande
# ----
#
# Apsilanti
#  Macht paßte. Als derSohn Apsilanti's geschlagen und in die
# ----
#
# treulose
#  und als auch der treulose Michael, Woywode der Moldau, mitallen
# ----
#
# Rußland
#  befreundeten Mächten, und besonders mitRußland, der geliebtesten und benachbartsten,
# ----
#
# Besils
#  der Truppen einwilligenwollte, welche Besils genannt werden, und unter dem
# ----
#
# Hr
#  starb am 2. April Hr. Apotheker Jakob Ulrich Irminger,
# ----
#
# Bundeszeitung
#  zu verdanken hat.Luzern. Die Bundeszeitung will die geringe Theilnahme des
# ----
#
# Uri
#  gewesen sei, als in früherenZeiten.Uri. Die Regierung, die sonst
# ----
#
# Bundeszeitung
#  derselben mit einzutreten. Die Bundeszeitung schreibtAenderung in dem Benehmen der
# ----
#
# Kloster
#  zu Magdenau,welches ursprünglich dem Kloster zu St. Gallen zugestanden hat,
# ----
#
# Wettingen
#  von dem Abte in Wettingen unbefugtausgeübt wurde, zu Handen der
# ----
#
# St
#  durch den Administrationsrathausgeübt werden. (St. G. Ztg.)Neuenburg. Die Petition
# ----
#
# Neuenburg
#  Administrationsrathausgeübt werden. (St. G. Ztg.)Neuenburg. Die Petition zu Gunsten
# ----
#
# St
#  von 49 Bürgern von St. Martin, in derMairie von
# ----
#
# Mairie
#  von St. Martin, in derMairie von Valangin, unterschrieben worden, und
# ----
#
# St
#  Valangin, unterschrieben worden, und St. Martin ist geradediejenige Gemeinde,
# ----
#
# von
#  die in den Unruhen von 1831 am treuesten zurRegierung gehalten
# ----
#
# P
#  Unterschrift vor: „Da uns P. L. Eward-Bourquin (der Urheberder
# ----
#
# Hrn
#  können, und wir beauftragen damitHrn. Baron v. Chambrier, Maire
# ----
#
# Die
#  Maire von Valangin."""" — Die Helvetie,die diese und andere Details
# ----
#
# Hrn
#  Worte,die der Bruder dieses Hrn. v. Chambrier im Jahr
# ----
#
# Havre
#  nach Orleansund nach dem Havre, sollen in den Bureaux
# ----
#
# Journal
#  ungleicher Ansicht.Man liest im Journal du Hayre: „Wir erfahren, daß
# ----
#
# Havre
#  Schweizerhaus seinen Korrespondenten im Havre den Auftrag gegeben hat,mehrere Waarenballen
# ----
#
# New
#  das die Reise nach New-York antreten wird. Da dieAufmerksamkeit
# ----
#
# nördliche
#  fürchten,die Schweiz und das nördliche Deutschland werden die Waaren, die
# ----
#
# Havre
#  die siebisher durch den Havre nach New-York sandten, nun den
# ----
#
# New
#  durch den Havre nach New-York sandten, nun den Weg
# ----
#
# London
#  sandten, nun den Weg überLondon oder Liverpool nehmen lassen? "—
# ----
#
# Liverpool
#  den Weg überLondon oder Liverpool nehmen lassen? "— Unter dem
# ----
#
# Herzog
#  3.)(Temps). Man versichert, der Herzog von Angouleme sei sehrkrank; die
# ----
#
# junge
#  einmal verschwunden wäre, der junge Herzog von Bordeaux sich schädlichen
# ----
#
# Fürstenthums
#  eineProtestation des Bauernstandes des Fürstenthums Osnabrück verursachthaben, die nun in
# ----
#
# hannoversche
#  viele neue Abgeordnete erwartet.Die hannoversche Zeitung widerspricht der Nachricht, daß
# ----
#
# hannoversche
#  keinen Bericht erstattet,versichert die hannoversche Zeitung. Hätte jene Nachricht nur
# ----
#
# Göttingen
#  Professor Gervinus ist aus Göttingen hier eingetroffen. Er wird, wie
# ----
#
# Kölner
#  Grenze, 20. Mai. Die Kölner Angelegenheit wird hoffentlich ruhig beendigt
# ----
#
# heint
#  Regierung Preußens tretenkönne, so scheint er doch veranlaßt worden zu
# ----
#
# Belgien
#  und zu handhaben. A. Z.)Belgien. Der Bürgermeister von Tilff,
# ----
#
# Bürgermeister
#  handhaben. A. Z.)Belgien. Der Bürgermeister von Tilff, Hr. Neef, ist
# ----
#
# Herrde
#  gewählt worden; sein Gegner, Herrde Longrée, welcher von der Priesterpartei
# ----
#
# Hrn
#  einnaher Verwandter des Ministers, Hrn. de Theux, ist, fiel
# ----
#
# Hr
#  ward hartnäckig bestritten, denn Hr. Neef hatte 445 und
# ----
#
# Hr
#  Neef hatte 445 und Hr. deLongrée 413 Stimmen.Türkei. Die
# ----
#
# Dresden
#  Zulassenund Gnade wirksam sein können."Dresden, 26. Mai. Die Bevollmächtigten
# ----
#
# Europäischen
#  der in Bern erschienenen Europäischen Zeitungbekannt. Ein Werk über die
# ----
#
# 1819
#  über die Freimaurerei ist 1819 von ihm in Aarauerschienen
# ----
#
# Aarauerschienen
#  1819 von ihm in Aarauerschienen
# ----
#
# Iratien
#  braucht, um Euch zu besiegen."Iratien. Neapel. Die unterm 10.
# ----
#
# Gott
#  Im Eingange ruftder König Gott zum Zeugen der Reinheit seiner
# ----
#
# Preußenverein
#  20. d. zwischen dem Preußenverein und dem demokratischen Verein zu
# ----
#
# demokratischen
#  dem Preußenverein und dem demokratischen Verein zu Schlägereien. Laut einer
# ----
#
# Fr
#  Schlägereien. Laut einer Korrespondenz derFr. O. P. Z. bediente
# ----
#
# Preußenverein
#  Z. bediente sich der Preußenverein eines Lokals, dasder Demokratenverein zu
# ----
#
# Demokratenverein
#  Preußenverein eines Lokals, dasder Demokratenverein zu seinen Zusammenkünften benutzte unddieser
# ----
#
# RepublikanerEdgar
#  Personen zweifelt. Auch der RepublikanerEdgar Bauer ist arg zugerichtet. So
# ----
#
# Berlin
#  wie in Folge dieser AuftritteBerlin selbst in Aufregung gerieth. Eine
# ----
#
# Unter
#  10 Führern der Arbeiter. Unter den Linden blieben jedochnamhafte Gruppen
# ----
#
# Präsidenten
#  „ordentliche Generalversammlung"""" wurdevon ihrem Präsidenten, Hrn. Dr. Escher, mit
# ----
#
# Hrn
#  Generalversammlung"""" wurdevon ihrem Präsidenten, Hrn. Dr. Escher, mit der
# ----
#
# Hr
#  Im Namendes Verwaltungsrathes referirte Hr. Ott-Imhof über diesebeiden Gegenstände
# ----
#
# Hr
#  Direktion fielen in Austritt: Hr. Dr. Escherund Hr. Nationalrath
# ----
#
# Hrn
#  Ferner waren die Stellendes Hrn. Dr. Kern und Oberst
# ----
#
# Hr
#  1939 Votanten, gewählt: 1) Hr. Dr. A. Eschermit 1934
# ----
#
# Hr
#  Eschermit 1934 Stimmen; 2) Hr. Kreis-Postdirektor Stoll mit1852 Stimmen;
# ----
#
# Hr
#  Stoll mit1852 Stimmen; 3) Hr. Betriebsdirektor Schweizer mit1790 Stimmen;
# ----
#
# Hr
#  Schweizer mit1790 Stimmen; 4) Hr. Ständerath Häberlin in Weinfelden
# ----
#
# Hrn
#  1727 von 1735 Stimmen: Hrn Dr.Alfred Escher. Unter der ausscheidenden
# ----
#
# Hr
#  des Verwaltungsrathes befindet sich Hr. M.Escher-Heß, Präsident dieser Behörde,
# ----
#
# austretenden
#  sich die Versammlung, um demaustretenden Hrn. Escher-Heß den wärmsten Dank
# ----
#
# Stadtpräsident
#  Verwaltungsrathes gewählt: die Herren Stadtpräsident Steiner imWinterthur, Nationalrath Wäffler-Egli in
# ----
#
# Winterthur
#  die Herren Stadtpräsident Steiner imWinterthur, Nationalrath Wäffler-Egli in Winterthur,Präsident
# ----
#
# Zürich
#  in Zürich, Nationalrath Fierz inZürich, Oberstl. v. Muralt in
# ----
#
# Oberstl
#  Zürich, Nationalrath Fierz inZürich, Oberstl. v. Muralt in Zürich,
# ----
#
# alt
#  v. Muralt in Zürich, alt RegierungsrathMüller in Winterthur, Bezirksgerichtspräsident v.
# ----
#
# Blank-Arbenz
#  v. Zieglerl in Schaffhausen, Blank-Arbenz in Schaffhausen,alt Regierungsrath Hüni-Stettler, LandesstatthalterHanauer
# ----
#
# alt
#  in Schaffhausen, Blank-Arbenz in Schaffhausen,alt Regierungsrath Hüni-Stettler, LandesstatthalterHanauer in Baden,
# ----
#
# alt
#  Hüni-Stettler, LandesstatthalterHanauer in Baden, alt Regierungsrath Dr. Rüttimann,und Regierungsrath Dr.
# ----
#
# Regierungsrath
#  LandesstatthalterHanauer in Baden, alt Regierungsrath Dr. Rüttimann,und Regierungsrath Dr. Keller
# ----
#
# Nr
#  erbost über dieMittheilung in Nr. 184 der N. Z.
# ----
#
# Winterthurer
#  sucht den Lärm,welchen der Winterthurer Stadtsängerverein in seiner Nr. 153geschlagen
# ----
#
# Landboten
#  das Letztere wollen wir demLandboten im Vertrauen mittheilen, daß das
# ----
#
# Landbote
#  Charakter angenommen, über welchen derLandbote sich nun beklagt. Hoffen wir
# ----
#
# Berner
#  haben, feststeht.— Von der Berner Liedertafel kommt ein Pökal im
# ----
#
# Zürich
#  das eidg. Sängerfest nach Zürich.— Hr. Hauptmann Senn von
# ----
#
# Hr
#  eidg. Sängerfest nach Zürich.— Hr. Hauptmann Senn von Liestal,
# ----
#
# Liestal
#  Hr. Hauptmann Senn von Liestal, welcher seit 1. Julidie
# ----
#
# Zürcherschen
#  1. Julidie Redaktion des Zürcherschen Intelligenzblattes führt, hatfrüher die Basellandschaftliche
# ----
#
# Basellandschaftliche
#  Intelligenzblattes führt, hatfrüher die Basellandschaftliche Zeitung, eines der bestbesorgten Schweizerblätter,
# ----
#
# Basellandschaftliche
#  bestbesorgten Schweizerblätter, redigirt.Baselland. Die Basellandschaftliche Zeitung vernimmt aus Muttenz: Eine
# ----
#
# Genfer
#  Tagen beim Baden im Genfer-See ertrank und deren Mann
# ----
#
# N
#  gleiche Blatt stimmt der N. Z. Z. bei, daß
# ----
#
# Liestal
#  Faßböden, Uhrengehäusen u. dgl.in Liestal erschienenen Zeugen als ein „Kameel"
# ----
#
# Ermatingen
#  hat einen guten Magen.Thurgau. Ermatingen. Unserm paritätischenKirchspielsarmenfond ist vom
# ----
#
# Wallis
#  eineSchenkung von Fr. 1000 zugekommen.Wallis. Die Gazette berichtet, am
# ----
#
# Gazette
#  Fr. 1000 zugekommen.Wallis. Die Gazette berichtet, am 26. Juni Abendssei
# ----
#
# Trogenwald
#  der dem Staat gehörige Trogenwald im Turtmanthaleine Beute der Flammen
# ----
#
# Turtmanthaleine
#  Staat gehörige Trogenwald im Turtmanthaleine Beute der Flammen geworden, die
# ----
#
# DorfLuc
#  kam. Ebenso soll das DorfLuc im benachbarten Einsischthal von einer
# ----
#
# Einsischthal
#  das DorfLuc im benachbarten Einsischthal von einer starken Feuersbrunst heimgesucht
# ----
#
# Schneider
#  Zank und Streit. Alsnämlich Schneider Krebser auf die Liste gesetzt
# ----
#
# Krebser
#  eigeneWahl, die der des Krebser vorausgegangen war, annullirtwerde, worauf laut
# ----
#
# Dr
#  allmälig gestillt werden konnte. Dr. Reiser, der vorgeschlagen gewesen,
# ----
#
# Dr
#  die HH. Direktor Zangger, Dr. Weisflog, KarlBürkli und Dr.
# ----
#
# Dr
#  Dr. Weisflog, KarlBürkli und Dr. Locher gesetzt wurden.— Der
# ----
#
# Stadtverein
#  Locher gesetzt wurden.— Der Stadtverein Zürich hat in seiner Versammlung
# ----
#
# HH
#  nächsten Sonntag festgesetzt: Die HH.Stadtschreiber Escher, Oberrichter Escher, StadtrathLandolt,
# ----
#
# Oberrichter
#  festgesetzt: Die HH.Stadtschreiber Escher, Oberrichter Escher, StadtrathLandolt, Prof. Rüttimann, Regierungspräsident
# ----
#
# Prof
#  Escher, Oberrichter Escher, StadtrathLandolt, Prof. Rüttimann, Regierungspräsident Suter,Fürsprech Mousson,
# ----
#
# Prof
#  Kommandant Bürkli, RR. Hagenbuch, Prof. G. v. Wyß, Antistes
# ----
#
# Strehler
#  Wyß, Antistes Finsler, ForstmeisterMeister, Strehler z. Schiff, Oberst Ziegler, Oberst
# ----
#
# Prof
#  Oberst Ziegler, Oberst Pestalozzi, Prof. Landolt und Oberrichter Gwalter.—
# ----
#
# Oberrichter
#  Pestalozzi, Prof. Landolt und Oberrichter Gwalter.— (Korr.*) Die Kopfbedeckungsfrage fängt
# ----
#
# Georgia
#  auf seinem denkwürdigen Zugedurch Georgia, daß der kühne Reiterführer
# ----
#
# kluge
#  der kühne Reiterführer Stuart, derkluge Stratege Lee für sich und
# ----
#
# Württemberg
#  praktisch erwiesen. Unsere Nachbarn inWürttemberg wurden vor zwei Jahren mit
# ----
#
# Hr
#  Bureau geschritten.Zum Präsidenten wurde Hr. Locher gewählt, zum VizePräsidenten
# ----
#
# Hrn
#  Fürsprech Fries (nach Ablehnung vonHrn. Schoch-Rüegg, der nur unter
# ----
#
# Hr
#  Entlassung aus dem Verfassungsrath zurückziehe;Hr. Locher schlug dieß rund
# ----
#
# Hrn
#  rund ab). Das Sekretariat wurdeHrn. Adolf Vögeli, Ingenieur, übertragen.
# ----
#
# Schoch
#  übertragen. In seinerAntwort an Schoch-Rüegg nahm Hr. Locher Veranlassung,
# ----
#
# Hr
#  seinerAntwort an Schoch-Rüegg nahm Hr. Locher Veranlassung, hervorzuheben, wie
# ----
#
# Dr
#  Arbeiter ihm im Prozessegegen Dr. Ullmer beigestanden, und wie
# ----
#
# Frei
#  als seine Strohmänner bezeichnet, Frei undClement, in sozialistischer Hinsicht nicht
# ----
#
# Clement
#  seine Strohmänner bezeichnet, Frei undClement, in sozialistischer Hinsicht nicht
# ----
#
# Clement
#  letztern glaube er, daß wederClement noch die Arbeiterversammlungen das Problemlösen
# ----
#
# Hr
#  ohne Widerspruch stillschweigend gutgeheißen. Hr. Dr. Locher erbietet sich,
# ----
#
# Hr
#  zuunterschreiben.Schließlich erhebt sich noch Hr. Bary und redet fürfreie
# ----
#
# RabrlihDaß
# Aus Spanien. 61. RabrlihDaß Madrid eine uralte Stadt sei,
# ----
#
# Madrid
#  zu tragen pflegten, erwiesen, daßMadrid zur Zeit des Cadmus schon
# ----
#
# Escorial
#  Fortsetzung von: Aus dem Escorial.zifferte Inschriften, welche man beim
# ----
#
# das
#  nach der Sündfluth erbautund das Jahr der Gnade 1859 ist,
# ----
#
# dem
#  z. B. ein aus dem XVI. Jahrhundertstammender, mit dem Titel:
# ----
#
# Adams
#  Jahre nach der Schöpfung Adams und1554 nach der Sündfluth, zu
# ----
#
# Stadt
#  vor Christi Geburt, wurdedie Stadt Zürich erbaut von einem heidnischen
# ----
#
# Madrid
#  Kunde über die Existenz vonMadrid stammt aus dem XI. Jahrhundert;
# ----
#
# dem
#  Existenz vonMadrid stammt aus dem XI. Jahrhundert; eine gewisseBedeutung erhält
# ----
#
# im
#  erhält die Stadt erst im XIV. Freilich trittsie vollständig zurück
# ----
#
# Toledo
#  Residenzen dereinzelnen Reiche, wie Toledo, Cordoba, Granada, Leon,Burgos, Zaragoza
# ----
#
# Cordoba
#  dereinzelnen Reiche, wie Toledo, Cordoba, Granada, Leon,Burgos, Zaragoza u.
# ----
#
# zu
#  s. f. Als endlich zu Ende des XV.Jahrhunderts die katholischen
# ----
#
# einheitlichen
#  dachte zuerst daran, dem einheitlichen Spanien eine Hauptstadt zu geben
# ----
#
# Toledo
#  und zog dem romantischen Toledo, dem blühenden Sevilla, dem
# ----
#
# Sevilla
#  romantischen Toledo, dem blühenden Sevilla, dem unvergleichlichen Granadadas öde
# ----
#
# Granadadas
#  blühenden Sevilla, dem unvergleichlichen Granadadas öde Madrid vor.Sollte es wahr
# ----
#
# seit
#  Entholzung des Landes erst seit dem XVI. Jahrhundert vorgenommen worden
# ----
#
# Madrider
#  wüßte nicht, daß die Madrider Aerzteseither eine Abnahme der Fälle
# ----
#
# Dänemarkund
#  ersten beiden Kriegen, gegen Dänemarkund Oesterreich — der dritte fand
# ----
#
# Deutschlandseit
#  der auswärtigen Politik scheint Deutschlandseit dem Weggange Bismarck's von Berlin
# ----
#
# Bismarck
#  verschwunden. Diese Taktik ist vonBismarck stets geübt worden, wenn er
# ----
#
# Bismarck'schen
#  einzumischen. Nachden Prinzipien der Bismarck'schen Politik ist esnun ganz und
# ----
#
# Andrassy
#  er die enge Verbindung mitAndrassy aufs deutlichste ausgesprochen und Andrafsy
# ----
#
# Andrafsy
#  aufs deutlichste ausgesprochen und Andrafsy hat seinerseits gethan, was er
# ----
#
# Andrassy
#  Vertrauen zu rechtfertigen.Hält sich Andrassy, so bleibt das Verhältniß
# ----
#
# Centralasien
#  Arbeit Rußlands, seinen Einfluß aufCentralasien zu begründen, mit einem kühnenSchlage
# ----
#
# Afghanistan
#  zu vernichten. Gelingt es ihnen,Afghanistan festen Fuß zu fassen, so
# ----
#
# Indien
#  fassen, so ist nicht mehrIndien von Rußland bedroht, sondern die
# ----
#
# Rußlandsaus
#  sieht es im Innern Rußlandsaus und Manche glauben, daß eine
# ----
#
# konservativ
# Eidgenossenschaft.In den Organen der konservativ-katholischenPartei entspinnt sich eine neue,
# ----
#
# Solothurner
#  desMilitärwesens, wobei die „Ostschweiz"der „Solothurner Anzeiger" und die „Liberté" vonFreiburg
# ----
#
# Freiburg
#  Anzeiger" und die „Liberté" vonFreiburg als Hauptredner auftreten, während das„Vaterland"
# ----
#
# Vaterland
#  als Hauptredner auftreten, während das„Vaterland" vorerst sich mit einigen
# ----
#
# Solothurner
#  Zwischenbemerkungen begnügt.Sowohl „Ostschweiz" als „Solothurner Anzeiger" zogen bei ihren Erwägungen
# ----
#
# Lausanner
#  der des „Genevois" und derLausanner „Revue" Aehnlichkeit hat, handelt essich
# ----
#
# 1875
#  schlimm gekommen, wie man 1875 geglaubthatte, so rühre dies lediglich
# ----
#
# Freiburg
#  (wahrscheinlich am meisten in Freiburg!!).Vor vierzehn Jahren hat die
# ----
#
# Liberte
#  Jahren hat die nämliche „Liberte"und ihr Anhang Zeter und
# ----
#
# Solothurner
#  Antwort, welche die „Liberte" dem„Solothurner Anzeiger" gibt, der da gesagt
# ----
#
# AdolfGuyer
#  beschlägt den Rekurs des AdolfGuyer-Zeller in Zürich gegen den
# ----
#
# Bundesversammlung
#  Rekurrenten hat Professor Vogt derBundesversammlung ein Rekursmemorial eingereicht, welches folgendes
# ----
#
# Guyer
#  Bundesverfassung, den Rekurs des Guyer begründeterklären und den Beschluß des
# ----
#
# Bürgliterrasse
#  1888 betreffend die Expropriationder Bürgliterrasse zum Zwecke eines Kirchenbaues in
# ----
#
# Engeaufheben
#  Zwecke eines Kirchenbaues in Engeaufheben."Kellersberger erstattet für den Ausschuß
# ----
#
# Kellersberger
#  Zwecke eines Kirchenbaues in Engeaufheben."Kellersberger erstattet für den Ausschuß Bericht.Der
# ----
#
# Kirchgemeinde
#  od dadurch, daß der Kirchgemeinde Enge dasExpropriationsrecht eingeräumt wurde, Artikel
# ----
#
# Bundesverfassung
#  Artikel 50, Absatz2 der Bundesverfassung Anwendung zu finden habe,welcher vorschreibt,
# ----
#
# KantonsZürich
#  Verfassung und Gesetz des KantonsZürich hatte im vorliegenden Fall der
# ----
#
# Bundesgericht
#  öffentliches Unternehmen sei. Das Bundesgericht hat zu entscheiden, ob die
# ----
#
# Bürgliterrasse
#  für die Expropriation der Bürgliterrasse gegeben seien. Der Bundesversammlung erübrigt
# ----
#
# Guyer
#  auf die Rechte des Guyer? Die Frage istzu verneinen.
# ----
#
# Kirchgemeinde
#  Frage istzu verneinen. Die Kirchgemeinde Enge ist ein Organ,welches sich
# ----
#
# Kantons
#  Verfassung und Gesetz des Kantons Zürichstützt. Sie ist ein öffentliches
# ----
#
# Enge
#  Daß der Kirchenbau in Enge, überhaupt die Kirche,im öffentlichen
# ----
#
# Kirchgemeinde
#  läßt. Allein was thut dieKirchgemeinde Enge? Sie greift weder in's
# ----
#
# Bundesversammlung
#  kann da nicht die Bundesversammlung, sondern lediglich das Bundesgericht
# ----
#
# Bundesgericht
#  Bundesversammlung, sondern lediglich das Bundesgericht Remedur schaffen. Würdedie Kirchgemeinde Enge
# ----
#
# Kirchgemeinde
#  Bundesgericht Remedur schaffen. Würdedie Kirchgemeinde Enge verlangen, daß jeder Gemeindeeinwohner
# ----
#
# Gobat
#  beantragt einstimmigdie Abweisung des Rekurses.Gobat erwähnt, es handle sich hier
# ----
#
# Kirchgemeinde
#  Fragevon großer Tragweite. Die Kirchgemeinde Enge hätte verschiedene Bauplätze gehabt.
# ----
#
# Kirchgemeinde
#  läßt. DieFrage, ob der Kirchgemeinde Enge das Expropriationsrecht zustehe, hat
# ----
#
# Bundesgericht
#  Expropriationsrecht zustehe, hat das Bundesgericht zu entscheiden. Alleinim Vorbeigehen ist
# ----
#
# Bürgliterrasse
#  in der Expropriation der Bürgliterrasse einen Eingriff, wie Art. 50
# ----
#
# Expropriaten
#  sich auf den Standpunkt desExpropriaten Guyer stellen. Offenbar stellt die
# ----
#
# Guyer
#  auf den Standpunkt desExpropriaten Guyer stellen. Offenbar stellt die Expropriation
# ----
#
# Guyer
#  Eingriff dar. Man sagt, Guyer wird entschädigt. Das ist richtig.
# ----
#
# Bürgliterrasse
#  entrichten.Allein die Abtretung der Bürgliterrasse ist mehr als eineSteuer.Bundesrath Ruchonnet:
# ----
#
# protestantischen
#  offenbar Guyer selber zur protestantischen Kirche gehört. Man verlangt von
# ----
#
# Guyer
#  gehört. Man verlangt von Guyer-Zeller kein Opfer, da erfür
# ----
#
# Bundesgericht
#  muß er sich ans Bundesgericht wenden.Bei einem Kirchenbau handelt es
# ----
#
# Kellersberger
#  Museums kein öffentliches Interesseerblicken. Kellersberger wendet sich gegen verschiedeneBehauptungen Gobats.Vizepräsident
# ----
#
# Gobats
#  wendet sich gegen verschiedeneBehauptungen Gobats.Vizepräsident Dr. Hoffmann: Man hat
# ----
#
# Guyer
#  es, wenn der Rekurs desGuyer gutgeheißen würde. Denn über die
# ----
#
# Gobat
#  allen gegen eine Stimme (Gobat) wird daraufder Rekurs abgewiesen.Der
# ----
#
# Dr
#  507,289 Fr. ein (Berichterstatter Dr. Reali).Der Ausschuß beantragt einstimmig
# ----
#
# KantonsZürich
#  wenn der Hochschule des KantonsZürich solche Vortheile zukommen, allein man
# ----
#
# eidgenössischen
#  müssen wir auch am eidgenössischen Polytechnikum eine Stätte bereiten. Einen
# ----
#
# Zürich
#  Stätte bereiten. Einen Neid aufZürich brauchen wir nicht zu haben.
# ----
#
# Dr
#  sah, wie dieEinrichtungen getroffen waren.Dr. Reali bemerkt, er habe
# ----
#
# Speichergasse
#  in Bern an der Speichergasse einen Bauplatz zum Preis von
# ----
#
# Bundesrathe
#  wird. Der Ausschuß empfiehltdem Bundesrathe zu untersuchen, ob nicht ein
# ----
#
# Zurlindenstraße
#  im scharfen Trabe durch dieZurlindenstraße gefahren. Als er um eine
# ----
#
# daselbst
#  kam, gewahrte er das daselbst befindliche zweijährige Mädchen Ida Wolfensperger
# ----
#
# frühere
#  Tage an innerer Verblutungstarb.Der frühere Buchhalter einer Bank in ZürichEugen
# ----
#
# am
#  Zürich geb. 1872 gab am 27.August 1897 einem Bankhause in
# ----
#
# Eidgen
#  London angeblich imNamen der Eidgen. Bank in Zürich, indem
# ----
#
# Credit
#  40 Lstr. 10 an denCredit Lyonais für Rechnung eines Kaufmanns
# ----
#
# Zürich
#  für Rechnung eines Kaufmanns inZürich auszuzahlen. Von diesem Kaufmann bezog
# ----
#
# Frey
#  Fr. 20.Im weitern betrog Frey einen Briefträger um 500 Fr.,indem
# ----
#
# Frey
#  inein Landesproduktengeschäft einlegen. Endlich entwendeteFrey noch englische Briefmarken im Werte
# ----
#
# Höngg
#  Neu-Läßig, Preußen, wohnhaft gewesen inHöngg, hatte am 9. August
# ----
#
# Rümlang
#  Uhr dem Gemeindegutsverwalter Meier inRümlang aus dessen Schreibpult in der
# ----
#
# Geld
#  in bar entwendet. Das Geld gehörte der Gemeinde Rümlang. Rudolf
# ----
#
# Offiziersgesellschaft
#  daß die Versammlung der Offiziersgesellschaft des Kantons Zürich dieses Jahr
# ----
#
# Winterthur
#  Kantons Zürich dieses Jahr inWinterthur nächsten Sonntag stattfindet. Herr OberstJ.
# ----
#
# Deifin
#  gewiß gerne kameradschaftliche Anerkennung gezollt.Deifin.Der Tessiner Staatsrat sah sich
# ----
#
# Caneggio
#  Zeit ablieferten. Genannt werden Caneggio, Bogno, Crana und Ponte
# ----
#
# Ponte
#  Caneggio, Bogno, Crana und Ponte Valentino.rebrigens beträgt die Buße jeweilen
# ----
#
# Wallis
#  die Buße jeweilen nur fünfFranken.Wallis.Der Regierungsrat hat den Modus
# ----
#
# Bergdörfchens
#  der Liebesgaben unter die AbgebranntendesBergdörfchens Randogne endgültig dahin festgestellt, daß
# ----
#
# Schweizerische
# Kleine Mitteilungen.— Der Schweizerische Verein fürfreies Christentum hält Sonntag
# ----
#
# Interlaken
#  Montag 15. Juni in Interlaken seine 19. Hauptversammlung ab. Er
# ----
#
# Schweizerische
#  1 der Vereinsstatuten lautet: „DerSchweizerische Verein für freies Christentum hat
# ----
#
# vom
#  Zweck hat unser Verein vom denkwürdigenJahr 1870 an, in dem
# ----
#
# evangelischen
#  erhob, zum Segen der evangelischen Schweizerkirche, ja wir dürfen sagen
# ----
#
# evangelischenKirche
#  den Richtungen in der evangelischenKirche mitbegründen helfen. Wenn auch sein
# ----
#
# Unterseen
#  Gottesdienst in der Kirche zuUnterseen, Sonntag 5½ Uhr und
# ----
#
# Interlakenund
#  recht zahlreiche Hörerschaft aus Interlakenund dem ganzen Vaterlande anziehen und
# ----
#
# Dekan
#  der Präsidialbericht erstattet und wirdDekan Hosang aus Pontresina reden über
# ----
#
# Brienz
#  mit Anhalt und Gratiserfrischungin Brienz die Gäste erfreuen. Dazu gewähren
# ----
#
# Berneroberlandbahnen
#  weitgehende Vergünstigungen: 1. Die Berneroberlandbahnen(Interlaken-Ost-Lauterbrunnen-Grindelwald-SchynigenPlatte, Lauterbrunnen-Müren) reduzierte Fahrpreisemit etwa
# ----
#
# Interlaken
#  weitgehende Vergünstigungen: 1. Die Berneroberlandbahnen(Interlaken-Ost-Lauterbrunnen-Grindelwald-SchynigenPlatte, Lauterbrunnen-Müren) reduzierte Fahrpreisemit etwa
# ----
#
# Lauterbrunnen
#  weitgehende Vergünstigungen: 1. Die Berneroberlandbahnen(Interlaken-Ost-Lauterbrunnen-Grindelwald-SchynigenPlatte, Lauterbrunnen-Müren) reduzierte Fahrpreisemit etwa
# ----
#
# Grindelwald
#  weitgehende Vergünstigungen: 1. Die Berneroberlandbahnen(Interlaken-Ost-Lauterbrunnen-Grindelwald-SchynigenPlatte, Lauterbrunnen-Müren) reduzierte Fahrpreisemit etwa
# ----
#
# SchynigenPlatte
#  weitgehende Vergünstigungen: 1. Die Berneroberlandbahnen(Interlaken-Ost-Lauterbrunnen-Grindelwald-SchynigenPlatte, Lauterbrunnen-Müren) reduzierte Fahrpreisemit etwa
# ----
#
# Lauterbrunnen
#  Vergünstigungen: 1. Die Berneroberlandbahnen(Interlaken-Ost-Lauterbrunnen-Grindelwald-SchynigenPlatte, Lauterbrunnen-Müren) reduzierte Fahrpreisemit etwa 35
# ----
#
# Müren
#  Vergünstigungen: 1. Die Berneroberlandbahnen(Interlaken-Ost-Lauterbrunnen-Grindelwald-SchynigenPlatte, Lauterbrunnen-Müren) reduzierte Fahrpreisemit etwa 35
# ----
#
# Wengernalpbahngesellschaft
#  vom 12.—17.Juni. 2. Die Wengernalpbahngesellschaft gewährt vom12.—18. Juni 50 Prozent
# ----
#
# Kurhausgesellschaft
#  Prozent Ermäßigung. 3. Die Kurhausgesellschaft Interlaken anerbietet freien Eintritt inden
# ----
#
# Küßnacht
#  Entgegenkommen. G. Sch.— In Küßnacht am Rigi findet nächsten Sonntag
# ----
#
# Küßnacht
#  Abfahrtszeiten von Zürich und Küßnacht: abZürich 8 Uhr 20
# ----
#
# Zürich
#  von Zürich und Küßnacht: abZürich 8 Uhr 20 vorm., an
# ----
#
# Küßnacht
#  Uhr 20 vorm., an Küßnacht 10 Uhr; abKüßnacht 9 Uhr
# ----
#
# Küßnacht
#  an Küßnacht 10 Uhr; abKüßnacht 9 Uhr 23 abends, an
# ----
#
# Männerchor
#  Zürich 11 Uhr 02. DerMännerchor Liederkranz Küßnacht singt als Begrüßungschor
# ----
#
# Schnyder
#  Begrüßungschor den Schweizersang von Schnyder. Vormittags von9 Uhr ab
# ----
#
# Gemischte
#  Am Nachmittag singt der Gemischte Chor Küßnachtden Einzug der Gäste
# ----
#
# Männerchor
#  Teil(am Nachmittag) spendet der Männerchor Außersihl alsfreien Vortrag, Kunstgesang, Faßbänders
# ----
#
# Pestalozzigesellschaft
# Lokales.— (M.-Korr.) Die Konzertkommission derPestalozzigesellschaft hat ihre diesjährigeWintertätigkeit begonnen. An
# ----
#
# Rossinis
#  Konzertgenüsse eröffnen und zwar mitRossinis glänzender Ouvertüre zum „Wilhelm Tell".Als
# ----
#
# Wilhelm
#  mitRossinis glänzender Ouvertüre zum „Wilhelm Tell".Als Instrumentalsolist wird sich Hr.
# ----
#
# Hr
#  Tell".Als Instrumentalsolist wird sich Hr. KonzertmeisterCarl Güther (Violine) in
# ----
#
# Sarasate
#  Güther (Violine) in „Zegeunerweisen" vonSarasate hören lassen. Als Vokalsolistin wurde
# ----
#
# FrauDr
#  lassen. Als Vokalsolistin wurde FrauDr. Elisabeth Meyer-von Orelli (Mezzo-Sopran)gewonnen,
# ----
#
# Hrn
#  ist. Der „LiederkranzAußersihl-Zürich" unter Hrn. J. WydlersDirektion hat ein
# ----
#
# Hr
#  für Chor undSoli hat Hr. Musikdirektor Rud. Mäder seine
# ----
#
# Mozart
#  Uhr „Die Zauberflöte" Oper vonMozart. Montag „Aida", Oper von
# ----
#
# Wagner
#  fliegende Holländer", Oper von Wagner,Abon., Anf. 8 Uhr. Samstag
# ----
#
# Flotow
#  Uhr. Samstag „Martha" Oper vonFlotow, Anf. 8 Uhr. Sonntag
# ----
#
# Pfauentheater
#  „Cavalleria Rusticana"; hierauf „Der Bajazzo",Pfauentheater. Sonntag „Die Wolke", Künstlerkomödie
# ----
#
# Huber
#  „Die Wolke", Künstlerkomödie von Huber. Montag „Was ihr wollt",
# ----
#
# Shakespeare
#  ihr wollt", einFastnachtspiel von Shakespeare. Freitag Roderich Benedix-Abend: „Die
# ----
#
# Roderich
#  einFastnachtspiel von Shakespeare. Freitag Roderich Benedix-Abend: „Die Dienstbotboten", Lustspiel, hierauf„Der
# ----
#
# Flers
#  Lustspiel von Caillavet und Flers. Anfangjeweilen abends 8 Uhr.—
# ----
#
# Niederdorfquartieraus
#  Detektive eine Razzia im Niederdorfquartieraus. Das Ergebnis war, daß
# ----
#
# Firma
#  In den Schaufenstern der Firma Forsteru. Altorfer an der Theaterstraße,
# ----
#
# Bastogne
#  Belgien haben unsere Kavallerieabteilungen Bastogne erreicht; mehr südlichsind unsere Truppen
# ----
#
# Habay
#  südlichsind unsere Truppen in Habay-La-Neuveeingerückt. In diesem Orte haben
# ----
#
# Kitterheim
#  Lothringen haben wir dieLinie Kitterheim-Neuvilliers-Cottesbein-Hochfelden-Stuthien-Chalscourt erreicht. Bière undMarmonthières wurden
# ----
#
# Neuvilliers
#  Lothringen haben wir dieLinie Kitterheim-Neuvilliers-Cottesbein-Hochfelden-Stuthien-Chalscourt erreicht. Bière undMarmonthières wurden
# ----
#
# Cottesbein
#  Lothringen haben wir dieLinie Kitterheim-Neuvilliers-Cottesbein-Hochfelden-Stuthien-Chalscourt erreicht. Bière undMarmonthières wurden
# ----
#
# Hochfelden
#  Lothringen haben wir dieLinie Kitterheim-Neuvilliers-Cottesbein-Hochfelden-Stuthien-Chalscourt erreicht. Bière undMarmonthières wurden
# ----
#
# Stuthien
#  Lothringen haben wir dieLinie Kitterheim-Neuvilliers-Cottesbein-Hochfelden-Stuthien-Chalscourt erreicht. Bière undMarmonthières wurden
# ----
#
# Chalscourt
#  Lothringen haben wir dieLinie Kitterheim-Neuvilliers-Cottesbein-Hochfelden-Stuthien-Chalscourt erreicht. Bière undMarmonthières wurden ebenfalls
# ----
#
# Bière
#  wir dieLinie Kitterheim-Neuvilliers-Cottesbein-Hochfelden-Stuthien-Chalscourt erreicht. Bière undMarmonthières wurden ebenfalls besetzt. DieseStädte
# ----
#
# Marmonthières
#  dieLinie Kitterheim-Neuvilliers-Cottesbein-Hochfelden-Stuthien-Chalscourt erreicht. Bière undMarmonthières wurden ebenfalls besetzt. DieseStädte waren
# ----
#
# Neu
#  ihren feierlichen Einzug in Neu-Breisach und Hüningen. InMarkelsheim wurde
# ----
#
# Hüningen
#  Einzug in Neu-Breisach und Hüningen. InMarkelsheim wurde ein bedeutendes
# ----
#
# Markelsheim
#  in Neu-Breisach und Hüningen. InMarkelsheim wurde ein bedeutendes Material genommen.London,
# ----
#
# Maas
#  rückten unsere Vorhutengegen die Maas südlich von Namur vor. Aufder
# ----
#
# Namur
#  die Maas südlich von Namur vor. Aufder linken haben sie
# ----
#
# GemblouxWavre
#  haben sie die Linie GemblouxWavre erreicht.Paris, 22. Nov. (Havas.) Amtlicher
# ----
#
#
#
# ----
#
# Paris
#  Novembermit dem Begleitschiff „Alexandra Woermann"folgen.Paris, 22. Nov. (Havas. Amtliche
# ----
#
# Havas
#  „Alexandra Woermann"folgen.Paris, 22. Nov. (Havas. Amtliche französische Mitteilung vom
# ----
#
# Vichten
#  am Abend die Linie Vichten-Norgen-Sartrange-Rentgen-Ruttekovenerreicht. Heute nachmittag haben unsere
# ----
#
# Norgen
#  am Abend die Linie Vichten-Norgen-Sartrange-Rentgen-Ruttekovenerreicht. Heute nachmittag haben unsere
# ----
#
# Sartrange
#  am Abend die Linie Vichten-Norgen-Sartrange-Rentgen-Ruttekovenerreicht. Heute nachmittag haben unsere
# ----
#
# Rentgen
#  am Abend die Linie Vichten-Norgen-Sartrange-Rentgen-Ruttekovenerreicht. Heute nachmittag haben unsere
# ----
#
# Ruttekovenerreicht
#  am Abend die Linie Vichten-Norgen-Sartrange-Rentgen-Ruttekovenerreicht. Heute nachmittag haben unsere
# ----
#
# Rosyth
#  am Donnerstag unterEskorte in Rosyth eingetroffen.London, 22. Nov. ag Die
# ----
#
# Reuter
#  22. Nov. ag Die Reuter-Agentur vernimmt, daß die britische
# ----
#
# Harwich
#  Nov. (Reuter.) Heute wurden inHarwich 19 deutsche Unterseeboote ausgeliefert. Es
# ----
#
# Agujhely
#  Da sie zwischen der Agujhely undPoestven die Eisenbahnschienen aufgerissen haben,sind
# ----
#
# Poestven
#  sie zwischen der Agujhely undPoestven die Eisenbahnschienen aufgerissen haben,sind die
# ----
#
# Sgeget
#  in Südungarn. Auf der LinieSgeget-Mako und Arad-Nagi-Szeben Brasso befinden
# ----
#
# Mako
#  in Südungarn. Auf der LinieSgeget-Mako und Arad-Nagi-Szeben Brasso befinden sich
# ----
#
# Arad
#  Auf der LinieSgeget-Mako und Arad-Nagi-Szeben Brasso befinden sich noch
# ----
#
# Nagi
#  Auf der LinieSgeget-Mako und Arad-Nagi-Szeben Brasso befinden sich noch
# ----
#
# Szeben
#  Auf der LinieSgeget-Mako und Arad-Nagi-Szeben Brasso befinden sich noch mehrere
# ----
#
# Marschalls
#  im Aeroplan Delegierte des Marschalls Foch, derenglische Major Großfield, der
# ----
#
# englische
#  Delegierte des Marschalls Foch, derenglische Major Großfield, der tschechoslowakische Major
# ----
#
# Marschall
#  a. ein Schreiben von Marschall Foch sowie einSchreiben von dem
# ----
#
# Minister
#  sowie einSchreiben von dem Minister des AuswärtigenBenès, welche die Mitteilung
# ----
#
# Oesterreich
#  der Waffenstillstandsbedingungen mit Deutschland undOesterreich-Ungarn zur Verfügung gestellt zu
# ----
#
# Entente
#  Der erste Vertreter der Entente, der Konanninopel betrat, war
# ----
#
# Konanninopel
#  Vertreter der Entente, der Konanninopel betrat, war der Vizeadmiral Sir
# ----
#
# Ismid
#  Flottein der Bucht von Ismid Anker werfen und begabsich in
# ----
#
# Generel
#  zweiter hoherFunktionär kam dann Generel Henry Wilson,dessen Truppen in den
# ----
#
# Führer
#  stille zu stehen. Die Führer der Kriegspartei, Enver und Talaat,
# ----
#
# Komitee
#  sich durchFlucht gerettet, das Komitee „Einheit undFortschritt" löste sich auf.
# ----
#
# Konstantinopel
#  löste sich auf. Wirtschaftlich zeigtKonstantinopel ein jammervolles Bild. Die ausgehungerte
# ----
#
# Alliierten
#  mangelten beim Einzug der Alliierten inerschreckender Weise. Heute beginnt sich
# ----
#
# Oesterreich
#  ihrem fatalistisch-apathischenGleichmut unerschüttert.Die Austösung Oesterreich-Angarns.Wien, 22. Nov. (W. K.-B.)
# ----
#
# Verbandes
#  In der gestrigenVollversammlung des Verbandes der deutschnationalen Parteien wurde, wie
# ----
#
# deutschnationalen
#  gestrigenVollversammlung des Verbandes der deutschnationalen Parteien wurde, wie parteiamtlich mitgeteilt
# ----
#
# deutschen
#  Zusammenschluß der deutsch-nationalen Partei,der deutschen Agrarpartei und der deutschradikalen Vereinigung
# ----
#
# deutschradikalen
#  deutschen Agrarpartei und der deutschradikalen Vereinigung vollzogen und diedrei Obmänner
# ----
#
# JosephvonHabsburg
#  22. Nov. (U. K.-B.) JosephvonHabsburg-Lothringen erschien heute vormittag auf
# ----
#
# Ackerbauministerium
#  heute vormittag auf dem Ackerbauministerium, wo er demAckerbauminister Huza
# ----
#
# ammlung
#  diesen Tagen von der Nationalversammlung erledigtwerden, befindet sich u. a.
# ----
#
# Schweiz
#  größeren Städte und Industriezentren derSchweiz. Begreiflicherweise mußte Zürich dasMuster
# ----
#
# Zürich
#  Industriezentren derSchweiz. Begreiflicherweise mußte Zürich dasMuster und das Beispiel sein,
# ----
#
# Münsterhof
#  nachmittagsgeplante Riesendemonstration auf dem Münsterhof durch das Kommando verboten worden.
# ----
#
# Grütlianer
#  Knebelung jederantibolschewistischen Presse, den „Grütlianer" inbegriffen, bringen sollte. Dagegen
# ----
#
# Milchbuck
#  erschien einKrawall auf dem Milchbuck geringfügig.Montag den 11. November. Der
# ----
#
# Kommandanten
#  die ZürcherBevölkerung in den Kommandanten der Ordnungstruppen, Herrn Oberst Sonderegger,
# ----
#
# Volksrecht
#  Schließungder Räume durchsetzten. Das „Volksrecht", daseinzige Blatt unserer Stadt
# ----
#
# Volksrecht
#  standen und von der „Volksrecht"-Druckerei hergestelltwaren. Der Kantonsrat, der
# ----
#
# Volkshaus
#  Gewalt der Nebenregierung im Volkshaus zu bringen. Glücklicherweise blieb die
# ----
#
# Schweiz
#  Verbindung Zürichs mit der übrigenSchweiz in vollem Umfang aufrecht; nur
# ----
#
# Bürgerlichen
#  verteilten die ersteNummer der „Bürgerlichen Presse Zürichs" Sonannte sich das
# ----
#
# ZürcherBuchdrucker
#  waren die Mitglieder der ZürcherBuchdrucker-Vereinigung, welche in jenenTagen an
# ----
#
# Bürgerlichen
#  vergriffen. Das Erscheinen der „Bürgerlichen Presse Zürichs" bildet den Wendepunkt
# ----
#
# Seefeld
#  Dienstag eine Massendemonstration im Seefeld durch Eingreifen der Truppenum jeden
# ----
#
# Volksrecht
#  Landesstreik. Vergeblich erklärte das „Volksrecht" die Verkündigung der unbedingten
# ----
#
# Oberstdivisionär
#  noch am gleichen Abend erließOberstdivisionär Sonderegger ein unzweideutigesVerbot des Streikpostenstehens
# ----
#
# Volksrecht
#  die Schließung der Druckerei des„Volksrecht". Hätte man bei frühern
# ----
#
# Theateraktiengesellschaft
#  Verband undstellten sich der Theateraktiengesellschaft zur Verfügung; die andern, die
# ----
#
# Kaufleuten
#  Kasino Hottingen und in „Kaufleuten" zu Protestgastspielenein. Die Tragödie
# ----
#
# Eidgenössischen
#  das vielsagende Abzeichen des Eidgenössischen Sängervereins, mit festlicher Begleitung in
# ----
#
# Lausanne
#  erweiterte Halle der Mustermessein Lausanne-Beaulieu.So hebt denn wieder eines
# ----
#
# Leman
#  an den Gestaden des Leman abgehalten worden ist. Dem Stolze,
# ----
#
# Welschland
#  Zürcher Sängerscharen zurFahrt ins Welschland, glückauf allen übrigenSchweizer Sängern,
# ----
#
# Eidgenössischen
#  seit dem 86jährigenBestehen des Eidgenössischen Sängervereins ziehtder Großteil der schweizerischen
# ----
#
# welsche
#  der schweizerischen Männerchöre indie welsche Schweiz, das Landes-Sängerturnierabzuhalten. Ihrer warten
# ----
#
# Leman
#  Landes-Sängerturnierabzuhalten. Ihrer warten am Leman noch herrlichere landschaftliche Ausblicke als
# ----
#
# als
#  noch herrlichere landschaftliche Ausblicke als 1912 in Neuenburg; gleich herzlich
# ----
#
# Jura
#  wie an den Abhängen desJura wird ihne nin Lausanne an
# ----
#
# von
#  27 mehr als am Festvon 1922 in Luzern und sieben
# ----
#
# Ostschweiz
#  dasDorado des schweizerischen Männergesanges, dieOstschweiz, beinahe die Hälfte, 68
# ----
#
# welsche
#  Zürich davonallein 49. Die welsche Schweiz, inbegriffen dievier festgebenden Lausanner
# ----
#
# La
#  die Società di cauto „La Melodia“ vonBellinzona. Wenn wir nicht
# ----
#
# Bellinzona
#  di cauto „La Melodia“ vonBellinzona. Wenn wir nicht irren,
# ----
#
# italienische
#  einem eidgenössischen Sängerfest, daßdie italienische Schweiz offiziell vertreten ist.In fünf
# ----
#
# Schweiz
#  eidgenössischen Sängerfest, daßdie italienische Schweiz offiziell vertreten ist.In fünf nach
# ----
#
# Musikkommission
#  der Einzelvorträge Qual, unddie Musikkommission des Eidgenössischen Sängervereins hat sie
# ----
#
# Angererund
#  vonfrüher meistgesungenen Chormeistern wie Angererund Sturm in Lausanne auch kein
# ----
#
# Sturm
#  meistgesungenen Chormeistern wie Angererund Sturm in Lausanne auch kein Ton
# ----
#
# Attenhofer
#  ist, daß der kernige Attenhofer nur noch in zwei Liedern
# ----
#
# Mendelssohn
#  Bearbeitungen, nicht fehlen, mögen Mendelssohn undSchumann, die besten Vorläufer des
# ----
#
# Schumann
#  nicht fehlen, mögen Mendelssohn undSchumann, die besten Vorläufer des
# ----
#
# vielgenannter
#  Am nächsten kommt ihmein vielgenannter Neuerer des Männerchorsaches,Erwin Lendvai, und
# ----
#
# Lavater
#  sieben Nennungen Hermann Suter. Lavater darf sich freuen,gleich oft gehört
# ----
#
# Vogler
#  wie Schubert; Curti,Meister und Vogler folgen mit je vier Chören,Lachner,
# ----
#
# Wiesner
#  je vier Chören,Lachner, Tinel, Wiesner und Pantillon mit drei,zweimal sind
# ----
#
# Pantillon
#  Chören,Lachner, Tinel, Wiesner und Pantillon mit drei,zweimal sind elf Chorkomponisten
# ----
#
# Thomas
#  Chorkomponisten vertreten, darunter Reger, Thomas, der neue Mann einer
# ----
#
# Andreae
#  und die SchweizerKempter und Andreae. 38 müssen sich begnügen,einmal
# ----
#
# Hug
#  Chöre aus dem Verlag Hug & Cie.stammen, weiterhin Beweis, wie
# ----
#
# Schweiz
#  weiterhin Beweis, wie führend dieSchweiz im Männerchorwesen in mancher Hinsichtgeworden
# ----
#
# Lausanne
#  Eindrucksvollsten. Die vier Hauptaufführungen inLausanne versprechen besonders Schönes. MitGlück ist
# ----
#
# Bruckner
#  Sinne bei,indem es für Bruckner und seine f-Moll-Messewirbt. Die nicht
# ----
#
# welschen
#  in Lausanne,in der festspielbewährten welschen Schweiz, durchJaques' Festspiel „Notre lays“
# ----
#
# Jaques
#  der festspielbewährten welschen Schweiz, durchJaques' Festspiel „Notre lays“ ganz
# ----
#
# Preisbildungskommission
#  zur Veröffentlichung Nr. 2der „Preisbildungskommission".II.*)Die gesamte Verschleißspanne.Unter Verschleißspanne des
# ----
#
# Zürich
#  Spanne um die Rückvergütung. InZürich ist eine objektive Spanne von
# ----
#
# St
#  Verhältnisse im Appenzell undin St. Gallen, wo eine der
# ----
#
# StadtZürich
#  Zürich Basel. In der StadtZürich entfallen 800 Einwohner auf 1
# ----
#
# A
#  wo die Konkurrenz des A. C. V.stark ins Gewicht
# ----
#
# A
#  der starke Rückhalt, den derA. C. V. an seinen
# ----
#
# L
#  Brotpreis der Schweiz, weilder L. V. Z. für sein
# ----
#
# Preisbildungs
#  den Anstoß zur Ernennung der„Preisbildungs-Kommission" gegeben hat, nämlich der
# ----
#
# Zürich
#  umzusetzen?Da ist zunächst, nachdem begreiflicherweiseZürich der Hauptschauplatz einer solchen Aktionsein
# ----
#
# L
#  Scharen das Brot beim L. V. Z., aufdaß er
# ----
#
# Bäckerverband
#  beschäftige und — mitdem Bäckerverband brechend — den Brotpreisherabzwinge. Es
# ----
#
# L
#  diese Aufforderung nutzlos ist. DerL. V. Z. hätte vor
# ----
#
# Migros
#  verzichten.Der Brotvertrieb durch die Migros A.-G.bietet ebenfalls keine volle Lösung,
# ----
#
# Bäckermeisterverbandes
#  Oeffentlichkeitsich gegen die Kartelldruckmethoden desBäckermeisterverbandes nachdrücklichst wendet,wenn die Getreideverwaltung „Pfuschern",
# ----
#
# Bäckermeisterverband
#  wäre es allerdings,wenn der Bäckermeisterverband jetzt von sich ausdie Initiative
# ----
#
# Zürich
#  man darfsagen, skandalösen Brotpreisunterschiedes vonZürich und Basel ergreifen und damit
# ----
#
# Gottzum
#  wir statt zum lieben Gottzum Bäckermeisterverband beten müßten: „Unsertäglich Brot
# ----
#
# Bäckermeisterverband
#  statt zum lieben Gottzum Bäckermeisterverband beten müßten: „Unsertäglich Brot gib
# ----
#
# Capitol
# Zürcher FilmrundschauCapitol. cs. „Der Tiger von
# ----
#
# cs
# Zürcher FilmrundschauCapitol. cs. „Der Tiger von Arizona""""
# ----
#
# Arizona
#  cs. „Der Tiger von Arizona"""" istein Männerfilm: wild, streitlustig,
# ----
#
# Virginia
#  der das schöne Mädchen (Virginia Bruce) verdient, das er liebt.
# ----
#
# WallaceBeery
#  paßte dazu besser als WallaceBeery, dieser Menschenklotz, der eine
# ----
#
# Apollo
#  Gesichter auftauchen, einsulminantes Tempo bekommen.Apollo. eb. Früher mußten die
# ----
#
# eb
#  auftauchen, einsulminantes Tempo bekommen.Apollo. eb. Früher mußten die Kaufleute
# ----
#
# Londongedrehten
#  Filmschauspieler. In dem in Londongedrehten, aber von Pariser Apachen
# ----
#
# AdolphWohlbrück
#  dies niemand anders als AdolphWohlbrück, der seine bevorzugte Kopfbedeckung,
# ----
#
# Walche
#  liebwerten, natürlichen Wesen sehr schönentspricht.Walche. bu. In dem Film
# ----
#
# bu
#  natürlichen Wesen sehr schönentspricht.Walche. bu. In dem Film „Das
# ----
#
# Emile
#  In dem Film „Das LebenEmile Zolas“ verstand es Wilhelm DieterlesRegie
# ----
#
# Emile
#  verstärkte.Paul Muni ist ein Emile Zola, dem man trotz allenEigenheiten
# ----
#
# 1906
#  Kunstseidenindustrie. Der Reserent, der 1906 vondieser Gesellschaft als Direktor gewonnen
# ----
#
# Dr
#  Direktor gewonnen wurde —wie Dr. Dürsteler in seinen Begrüßungsworten
# ----
#
# 1665
#  gedacht, Seide künstlich herzusteller.Schon 1665 schrieb der Engländer Robert Hoole,es
# ----
#
# Engländer
#  herzusteller.Schon 1665 schrieb der Engländer Robert Hoole,es sollte möglich sein,
# ----
#
# 1734
#  entscheidendenSchritt weiter, indem er 1734 auf die ldee kam,durch Verlestigung
# ----
#
# 1846
#  die der Seidenfaser ähnlich wäre.1846 entdeckte Christian Friedrich Schönbein, Professor
# ----
#
# 1855
#  Weise auchNitrozellulose genannt wird. 1855 schen wir den ausdem Jouxtale
# ----
#
# Jouxtale
#  schen wir den ausdem Jouxtale stammenden Lausanner Audemarssich mit Schönbeins
# ----
#
# Lausanner
#  den ausdem Jouxtale stammenden Lausanner Audemarssich mit Schönbeins Material beschäftigen;
# ----
#
# 1882
#  der honigdicken Flüssigkeit Fädenzichen. 1882 benützte man die Eigenschaft der
# ----
#
# 1889
#  das heißt denitrierte. Aber erst1889 konnte die erste technisch hergestellte
# ----
#
# weißbärtige
#  zu glänzenden Fäden Koagulierte. Derweißbärtige Erfinder, Graf Hilaire de Chardonnet,
# ----
#
# Chardonnet
#  Erfinder, Graf Hilaire de Chardonnet, mußte aber zugeben, daß
# ----
#
# Chardonnetscide
#  zu denitrieren, s0daß die Chardonnetscide als schönes und völlig gefahrloses
# ----
#
# 1896
#  auf den Markt kam. 1896 wurdeeine Versuchslabrik in Besançon gegründet,
# ----
#
# Chardonnet
#  in Besançon gegründet, an derChardonnet sein ganzes Vermögen von 6
# ----
#
# 1857
#  Vermögen von 6 MillionenFranken verlor.1857 beschrieb Schweizer im Journal fürpraktische
# ----
#
# Schweizer
#  6 MillionenFranken verlor.1857 beschrieb Schweizer im Journal fürpraktische Chemie die
# ----
#
# Journal
#  verlor.1857 beschrieb Schweizer im Journal fürpraktische Chemie die kuproammoniakale Schweizerlôsung:
# ----
#
# Schweizerlôsung
#  fürpraktische Chemie die kuproammoniakale Schweizerlôsung: 1890 stellte Gral Dupeissis
# ----
#
# 1890
#  Chemie die kuproammoniakale Schweizerlôsung: 1890 stellte Gral Dupeissis das sog.Kupfer-Ammoniak-Versahren
# ----
#
# Gral
#  kuproammoniakale Schweizerlôsung: 1890 stellte Gral Dupeissis das sog.Kupfer-Ammoniak-Versahren her, anCunstseidenindustriedessen
# ----
# Freméry
# ...
# ----
#
# Deutschland
#  Viscosegesellschalt in Emmenbrücke ist. InDeutschland finanzierte Graf Henckel vonDonnersmark das
# ----
#
# im
#  Papiermühleentstanden waren, in der im letzten Jahrzehnt des19. ahrhunderts Dr.
# ----
#
# 1907
#  „triste figure"; alsdann aber 1907 die bessern Apparate zur Verfügungwaren,
# ----
#
# Comptoir
#  heutige Hauptgruppe ist das „Comptoir des TextilesArtisicieles“. Die französische Viscose
# ----
#
# Schweiz
#  technische Bezichungen mit Belgien, derSchweiz und Italien, mit der englischen
# ----
#
# Courtauldsund
#  Italien, mit der englischen Courtauldsund diese wiederum mit der amerikanischen
# ----
#
# Cisa
#  an ihre Stelle tratendie „Cisa , die Snia viscosa (Gualino).
# ----
#
# DupontNemouxs
#  gingen auch Ableger zur DupontNemouxs-Gruppe in Köln-Rottweil, diedurch die
# ----
#
# Köln
#  Ableger zur DupontNemouxs-Gruppe in Köln-Rottweil, diedurch die Versailler Verträge
# ----
#
# Rottweil
#  Ableger zur DupontNemouxs-Gruppe in Köln-Rottweil, diedurch die Versailler Verträge
# ----
#
# Enka“
#  altbekannte Firmen sind die „Enka“ inden Niederlanden, die Dr. Hartogs,
# ----
#
# Niederlanden
#  sind die „Enka“ inden Niederlanden, die Dr. Hartogs, ein
# ----
#
# Dr
#  „Enka“ inden Niederlanden, die Dr. Hartogs, ein Volontär der
# ----
#
# Küttner
#  Courtaulds, prächtig entwickelte unddie Küttner in Sachsen, die gleichzeitig mit
# ----
#
# Société
#  Sachsen, die gleichzeitig mit derSociété de la Viscose in Emmenbrücke
# ----
#
# Japan
#  zu sein. Als Krisenvogel kamJapan zur Runstscidenindustrie; sein Produftionsanteil betrug
# ----
#
# 1923
#  Runstscidenindustrie; sein Produftionsanteil betrug 1923 350 000 lg. 1937 151
# ----
#
# 1937
#  1923 350 000 lg. 1937 151 Millionen Rg. das heißt
# ----
#
# Usines
#  der „Rhodiaseta“auch in den Usines du Rhone, und in Deutschlandvon
# ----
#
# Deutschlandvon
#  du Rhone, und in Deutschlandvon den I. G. Farben hergestellt,
# ----
#
# I
#  und in Deutschlandvon den I. G. Farben hergestellt, die
# ----
#
# Italienpflanzt
#  bietet, ist die Baumwolle; Italienpflanzt heute schon für seine Tellulose
# ----
#
# Schweizliegt
#  Kunstscidefäden, hergestellt. In der Schweizliegt ihre Verwendung noch in den
# ----
#
# Schweden
#  noch in den Anfängen; inSchweden, das doch keine autarkische
# ----
#
# von
#  Wohlener Hutlabrikation plötzlich nichtsmehr davon wissen wollte.Nach minutiésen Darlegungen über
# ----
#
# als
#  die Wirkereiund der Rundstuhl: als 1910 jemand vomStrümplewirken sprach, antwortete
# ----
#
# von
#  jemand vomStrümplewirken sprach, antwortete von Goumoéns:„Sagen Sie lieber gleich Regenschirme!"
# ----
#
# 1923
#  bis 60 Prozentins Ausland. 1923 hat die Emmenbrücke in Widnau-Heerbrugg
# ----
#
# Emmenbrücke
#  Ausland. 1923 hat die Emmenbrücke in Widnau-Heerbrugg im Rheintal eine
# ----
#
# Widnau
#  hat die Emmenbrücke in Widnau-Heerbrugg im Rheintal eine Zweigsabrikeröffnet.
# ----
#
# Heerbrugg
#  hat die Emmenbrücke in Widnau-Heerbrugg im Rheintal eine Zweigsabrikeröffnet. Inzwischen
# ----
#
# Rheintal
#  Emmenbrücke in Widnau-Heerbrugg im Rheintal eine Zweigsabrikeröffnet. Inzwischen hatte sich
# ----
#
# Feldmühle
#  hatte sich auch die Feldmühle, Norschach, auf Kunstseide umgestellt.Weitere
# ----
#
# Rheinfelden
#  („NovaSeta"-Kupfer und Acetat) in Rheinfelden(Viscose), in Steckborn (Viscose) und
# ----
#
# Das
#  seit 1929in Basel (Azetat). Das ahr 1932 brachte einenargen Rückschlag;
# ----
#
# 1937
#  1932 brachte einenargen Rückschlag; 1937 war infolge der Abwertungein Rekordjahr;
# ----
#
# 1938
#  infolge der Abwertungein Rekordjahr; 1938 wird wohl Einbußen verzeichnen. In
# ----
#
# 1936
#  In der Schweiz wurden 1936 an Viscose1651000 lg. 1937 1806
# ----
#
# 1937
#  1936 an Viscose1651000 lg. 1937 1806 000 kg. Aretat- undKupferseide
# ----
#
# 1936
#  000 kg. Aretat- undKupferseide 1936 299 000 lg und 1937
# ----
#
# 1937
#  299 000 lg und 1937 415 000 lgverbraucht. Der Totalkconsum
# ----
#
# 19363
#  Der Totalkconsum macht für 19363 062 000 lg und für
# ----
#
# 1937
#  000 lg und für 1937 3 526 000 lg aus.Den
# ----
#
# Dr
#  nochallerhand an den Tag. Dr. Dürsteler entkräftete diesen Trost,
# ----
#
# Prof
#  schönen Monographie entnommen, die Prof. Dr. H. Ed. Fierz,E.
# ----
#
# Fretx
#  Runstseide gewidmet hat.(Verlag Gebr. Fretx, Zürich, 1930)
# ----
#
# 1930
#  hat.(Verlag Gebr. Fretx, Zürich, 1930)
# ----
#
# BerlinNeben
#  Notenwechsel der bächte über BerlinNeben dem „Kalten Krieg" um die
# ----
#
# nationalsozialistischenDeutschland
#  sieüber die Armeen des nationalsozialistischenDeutschland errungen hat, 80 auszuwerten,dals Bedingungen
# ----
#
# Westmüchtestemmen
#  den beidenLändern herauszupressen. Die Westmüchtestemmen sich diesen Versuchen entgegen undkönnen
# ----
#
# Westmüchtezur
#  Gelingt es nämlich, die Westmüchtezur Räumung von Berlin und damit
# ----
#
# Mestmüchte
#  Und zudlem möchten sie dieMestmüchte zum ersten Schritt auf dem
# ----
#
# Unterhaus
#  und ihrerAufnahme dureh dus Unterhaus absicht —,dals die Westmüchte Berlin
# ----
#
# Rulland
#  ihr Rechtnicht preisgeben können. Rulland dugegenscheint an die Entsehlossenheit seiner
# ----
#
# Berlins
#  die sich aus der VerwaltungBerlins ergeben, vorsehlagen, unter der Voraussetzung
# ----
#
# Oesterreich
#  der Besetzung von Deutschland undOesterreich durch die vier Grolmächte, vielmehr
# ----
#
# Ostbloekekonferenz
#  in der Resolution der Ostbloekekonferenz vom 24. Juni enthalten war
# ----
#
# Berlins
#  seine absurdeMalsnahme einer Blockade Berlins. Dals wirkelich zwischen Grolimüchten
# ----
#
# Sowjetsone
#  Wührungsreform in Westdeutschland,welche die Sowjetsone der Gefahr aussetze,„dali die ganze
# ----
#
# Westmüchte
#  es stets die Absicht derWestmüchte gewesen war, die I'älnungsnesorm für
# ----
#
# Demarkationslinie
#  östlich und westlich der Demarkationslinie getroffenen Malsnahmen nicht undenkbar. Damit
# ----
#
# Deutschland
#  zu einer neuen Conserenz überDeutschland geschakfen. Würe dann aber nichteinfach
# ----
#
# Buropahilse
#  verhindern suchte, ist eingetreten. DieBuropahilse der Vereinigten Stuaten vonAmerikea beginnt
# ----
#
# Westdeutschlandsaus
#  Währungsreform ist die Wirtschaft Westdeutschlandsaus ihrer Erstarrung erweekt worden. DieUebertragung
# ----
#
# Roten
#  dort, wo derArm der Roten Armee nieht hinreiclit. Sowürde sich
# ----
#
# Viermächtebesprechungen
#  Rulland bei der Wiederaufnahmevon Viermächtebesprechungen über eine Gesamtregelung in einer
# ----
#
# Moskau
#  als während der Konferenzen vonMoskau und London.Das erkclärt, warum Rulsland
# ----
#
# Berlin
#  Pfandund Druckmittel könnte unter UmstündenBerlin gebraucht werden, und weiter riehtetsich
# ----
#
# Moskaus
#  weiter riehtetsich der Blieke Moskaus auf das Kulrgebiet.Sehion in der
# ----
#
# Warschau
#  der Resolution der Konkerens vonWarschau vom 24. Juni erheben die
# ----
#
# Ostbloekemüchte
#  24. Juni erheben die Ostbloekemüchte die Forderung, duss dus Rulirgebietunter
# ----
#
# Rulirgebietunter
#  die Forderung, duss dus Rulirgebietunter Viermüchtekontrolle gestellt werdensoll, und in
# ----
#
# Viermüchtekontrolle
#  Forderung, duss dus Rulirgebietunter Viermüchtekontrolle gestellt werdensoll, und in seiner
# ----
#
# Mloskau
#  Note vom 14. Juli gehtMloskau einen Sehritt weiter, indem es
# ----
#
# Deutschland
#  die zentralenBestimmungen zu verwirkelichen, wonachDeutschland als wirtschaktliche Einheit hättebehandelt werden
# ----
#
# Amerikka
#  Verhandlungspositionen sei jetzt noch günstig.Amerikka glaubt man wegen der Präsidentschaftswahlen
# ----
#
# Deweys
#  da weder bei einerWahl Deweys noch bei einer WiederwahlTrumans die
# ----
#
# Trumans
#  Deweys noch bei einer WiederwahlTrumans die Aullenpolitik Washingtons sichündern wird,
# ----
#
# Washingtons
#  einer WiederwahlTrumans die Aullenpolitik Washingtons sichündern wird, und weil die
# ----
#
# Frankpeich
#  beistungskühigkeit überhaupt nicht berühren. Frankpeich sicht manheute noch im Banne
# ----
#
# GroGönikannien
#  gegenüber Deutschland diktierte Unentschlossenheit. GroGönikannien und seineEntschlossenheit aber unterschätzen dieMuchthaber
# ----
#
# Kreml
#  aber unterschätzen dieMuchthaber im Kreml, genau wie die Nationalsozialisten
# ----
#
# ögxptische
#  Montag in Kairo ermordete ögxptische Ministerprüsident Mahmud Fahmi Al-Nostraschi Pascha
# ----
#
# Waldl
#  hinabgestiegen sind. Fxüherer Anbünger desWaldl, wie überhaupt alle ügpptisehen
# ----
#
# zweiten
#  ersten Mal als Verkehrsminister imzweiten Kahinett Nahns Pascha in den
# ----
#
# vom
#  den Vordergrund, das nur vom Jannar bis Juni 1930 im
# ----
#
# dritten
#  bekleidete er noch einmal imdritten Kabinett Nahas vom Mai 1936.
# ----
#
# Amed
#  seinem Parteikreund und Altersgenossen Amed Maher Pascha näher, dem Prisidenten
# ----
#
# Aexypten
#  unterzeichneten. Nach ihrer Rüelhehr unchAexypten gevannen sie als jüngere Mitglieder
# ----
#
# Wajd
#  Eindruck, als ob der Wajd in Londondie letzten Karten ausgespielt
# ----
#
# Londondie
#  ob der Wajd in Londondie letzten Karten ausgespielt und somit
# ----
#
# Wafd
#  setzte der eigentliehe Riiekgangdes Wafd in jenem Zeitpunkt ein. Als
# ----
#
# Wafd
#  Zeitpunkt ein. Als nämlichder Wafd gegründet wurde, uar das einzigeHiel
# ----
#
# Aeppptens
#  mit Grolbritannien, das die UnabhängigkeitAeppptens anerkennen sollte. Mnn weis, dnss
# ----
#
# Watd
#  weis, dnss dnsarabisehe Wort „Watd" niehts anderes als „Pelevation"
# ----
#
# NalasPuscha
#  Diesen Vertrag Untte nun NalasPuscha den Briten abgerungen. Die Rolle
# ----
#
# Wafd
#  Die Rolle der„Delegntion" des Wafd, war somit ausgespielt.Iu den
# ----
#
# Makram
#  der Purtei, vor allem Makram Eheid und ingeringerem Male Nahas,
# ----
#
# Nahas
#  Eheid und ingeringerem Male Nahas, s0, als ob sie
# ----
#
# Nokruschi
#  die zwei FreundeMnhier undl Nokruschi vom Watd los und gründetengemeinsum
# ----
#
# Watd
#  FreundeMnhier undl Nokruschi vom Watd los und gründetengemeinsum eine neue
# ----
#
# Gründer
#  die sie nach dem Gründer des Wufd, Sand Engblul, Sandistische
# ----
#
# imAuxust
#  seblieBzlich durch, und uls imAuxust 1939 Ali Maher Pascha, der
# ----
#
# li
#  und uls imAuxust 1939 Ali Maher Pascha, der BruderAhmeds, bei
# ----
#
# lm
#  l'rüsidenten, Nokraschi, dus Ereiebungsminiskerium an.lm Juni 1940 mutte Ali Mnher
# ----
#
# Ali
#  an.lm Juni 1940 mutte Ali Mnher wegen seiner prodentsehen Neigungen
# ----
#
# Hasenn
#  und Nokraschi wurdevom Knbinett Hasenn--Suliri Poseln uls Innenminisker, übernommen.
# ----
#
# Sabri
#  den Englündern anvertrautwerden.Das Cabinett Sabri blieb nur zwei Monnte umRuder.
# ----
#
# Wafdlnbinett
#  EnbinettHussein Sirry vom letzten Wafdlnbinett unterNalias Paschn abgelöst. Als im
# ----
#
# Nalias
#  Sirry vom letzten Wafdlnbinett unterNalias Paschn abgelöst. Als im Oktober
# ----
#
# Nulns
#  mußten, das das weitere VerbleibenNulns Paschns in der Regierung ihre
# ----
#
# Mnher
#  teilten unter sich die Sehlüsselstellungen.Mnher behielt kür sich das Innenministerium,
# ----
#
# Nokraschi
#  kür sich das Innenministerium, undNokraschi wurde AuBenminister. So untte er
# ----
#
# Mahers
#  mulz.Enter der Pührung Ahmed Mahers wurde dieügyptische Politik in das
# ----
#
# Maher
#  gesteuert. Diese Politik multe Maher schon nachwenigen Monaten mit seinem
# ----
#
# am
#  leben biisen. MaherPnscha wurde am 24. Februar 1945 von einem
# ----
#
# Aehsenmüehte
#  die Triegserklärung Aegyptens an dieAehsenmüehte angekinfligt hatte. E's war fürNokraschi
# ----
#
# Nokraschi
#  angekinfligt hatte. E's war fürNokraschi unter solehen Umstünden eine heileleAulgabe,
# ----
#
# Aesppten
#  dem Kriege versehürfte sich inAesppten der Nationalismus, dem Nokraschi entgegenzutreten
# ----
#
# Nokraschi
#  inAesppten der Nationalismus, dem Nokraschi entgegenzutreten verzuchte. Als Realpolitiker, derdie
# ----
#
# Landem
#  Als er die Verhandlungenmit Landem beginnen wollte, multe seine Regierung
# ----
#
# im
#  zeigte sich auch,als er im Februar 1946 der Polizei den
# ----
#
# Abbas
#  schielzen, die über die Abbas-Brücke indas Regierungsviertel eindringen wollten.
# ----
#
# um
#  Angst.Nnch Nokraschi Pnsehns Rüektritt um 15. Februar 1946 übernalun lsmail
# ----
#
# lsmail
#  15. Februar 1946 übernalun lsmail Sidlkey Pascin dasEnbinett, dus von
# ----
#
# A
#  PaschusCairo, 29. Der. ag (A'P) Das nationnle Bepräbnis von
# ----
#
# früheren
#  Alausokeum, dus für den früheren Ministerprüsidenten Ahmed Maher Pascha erlmut
# ----
#
# im
#  Maher Pascha erlmut wird, derim Februar 1945 ebenkulls ermordet worden
# ----
#
# AFF
#  MördersKairo, 29. Der. ag (AFF) Der Nörder Nokraschi Pasehas
# ----
#
# Sudan
#  der „MohammedanischenPrüdler", Politik im Sudan und in Paliistina.) DerNörder ist
# ----
#
# Aexypten
#  eine Untersuchungangeordnet lntte.Da in Aexypten seit Ausbruch des Krieges mitPaliistinn
# ----
#
# Paliistinn
#  seit Ausbruch des Krieges mitPaliistinn der Belugerungszustand herrscht, wirdder Mörder
# ----
#
# Sr
#  Erzbischof. Enthüllung der von Sr. Majestät dem Könige Ludwig
# ----
#
# Neumarkte
#  Bürgerwehr Kölns auf dem Neumarkte. 2) Morgens 11 Uhr:
# ----
#
# Neumarkte
#  des Festzuges auf dem Neumarkte. An diesem Zuge werden
# ----
#
# Neumarkt
#  und Glockengeläute um den Neumarkt herum durch die Apostelnstraßc, Apernstraße,
# ----
#
# Apostelnstraßc
#  Neumarkt herum durch die Apostelnstraßc, Apernstraße, am 9îijmcrtl;urm vorbei
# ----
#
# 9îijmcrtl
#  die Apostelnstraßc, Apernstraße, am 9îijmcrtl;urm vorbei durch die Mohrenstraße,
# ----
#
# Pfaffculhor
#  die Sachscnhauscnstraße, Marcellenstraße, das Pfaffculhor, über den neuen, freigelegten
# ----
#
# Wallrafsplatzc
#  Kitsch und südlich vom Wallrafsplatzc her bleiben abgesperrt. Dagegen werden
# ----
#
# D
#  hat aufgehört, Kaiser »on D e st exxe i d)
# ----
#
# Leipzig
#  Nachricht mit folgenden Worten: „Leipzig, 4. Dec., früh halb
# ----
#
# Olmütz
#  diesem Tage früh in Olmütz zu Gunsten des Erzherzogs Franz
# ----
#
# Oesterrcich
#  der Kaiserin eingetroffen ist." Oesterrcich wird nicht trauern, wenn es
# ----
#
# Sophie
#  Namen Franz Carl und Sophie hängt sich nun einmal in
# ----
#
# K
#  dem Vatcrlande opfern wollen. (K. Z.) — Der Kaiser
# ----
#
# Broatien
#  an den Banus »on Broatien erlassen: „Lieber Freiherr von lellachich
# ----
#
# Freiherr
#  »on Broatien erlassen: „Lieber Freiherr von lellachich ! Die Monarchie
# ----
#
# Köln
#  behaupten wissen wirb. Als Köln, 6. Dezember, 11 Uhr
# ----
#
# Preuß
#  octroyirte Verfassung. Der heutige „Preuß. StaatsAnzeiger" bringt nämlich 1)
# ----
#
# Handclsgcrichts
#  Zugleich ist wirklich der Handclsgcrichts-Präsidcnt von der Hcydtmitdem Portefeuille
# ----
#
# O
#  das Ministerium eingetreten. In O est er reich hat die
# ----
#
# Reichstage
#  gemacht : in dem Reichstage ist eine Proclamation des jungen
# ----
#
# Potsdam
#  beigedrucktem Königlichen Insiegel. Gegeben Potsdam, 5. Dec. 1848. Friedrich
# ----
#
# 5
#  Königlichen Insiegel. Gegeben Potsdam, 5. Dec. 1848. Friedrich Wilhelm.
# ----
#
# Graf
#  Friedrich Wilhelm. Das Staats-Ministerium. Graf von Brandenburg, von Ladenberg, von
# ----
#
# von
#  Wilhelm. Das Staats-Ministerium. Graf von Brandenburg, von Ladenberg, von ©trotta,
# ----
#
# von
#  Staats-Ministerium. Graf von Brandenburg, von Ladenberg, von ©trotta, von Manteuffel.
# ----
#
# von
#  von Brandenburg, von Ladenberg, von ©trotta, von Manteuffel. Rintclen. von
# ----
#
# Rintclen
#  von ©trotta, von Manteuffel. Rintclen. von der Hcydt. Träger
# ----
#
# von
#  ©trotta, von Manteuffel. Rintclen. von der Hcydt. Träger des Habsburg
# ----
#
# Ocstcrrcich
#  und NcvollitionirenS ist für Ocstcrrcich zu Ende; die Zeit der
# ----
#
# Köln
#  werbet uns willkommen fein! (Köln. Ztg.) Ich Ihnen die
# ----
#
# Dlmü
#  Meines Leopoldordens zu verleihen. Dlmü&, 24. November 1848. Ferdinand.
# ----
#
# 24
#  Leopoldordens zu verleihen. Dlmü&, 24. November 1848. Ferdinand. —
# ----
#
# K
#  3. Dezember ist ausgeblieben. (K. Z.) Üter bie SScrfaffung
# ----
#
# Preußenland
#  Liberalitätsregen auf das verdorrte Preußenland nie» dergerauscht sein soll, emsig
# ----
#
# Sonderbundes
#  nach den Siegen des Sonderbundes über die Radicale« von 1844
# ----
#
# DNS
#  ab. Moskau. 9. August (DNS.) Heute nachmit» tag sprach
# ----
#
# erste
#  nachmit» tag sprach der erste Sekretär der japanischen Botschaft in
# ----
#
# Schangfeng
#  200 Kilometer nördlich des Schangfeng-Gebietes, unweit de« Hanka-Weges). Dort
# ----
#
# Hanka
#  des Schangfeng-Gebietes, unweit de« Hanka-Weges). Dort hatte nach japanischer
# ----
#
# Pariser
# Ende der Pariser Verteidigungskonferenz Schaffung eines ständigen internationalen
# ----
#
# Beneluxstaaten
#  Großbritanniens, Frankreichs und der Beneluxstaaten beendeten gestern die Besprechungen mit
# ----
#
# Westunion
#  der fünf Staaten der Westunion, seien zur Errichtung eines
# ----
#
# Großbritanniens
#  verpflichteten sich die Minister Großbritanniens, Frankreichs, Hollands, Belgiens und
# ----
#
# Brüsseler
#  gemeinsamer Verteidigung gemäß dem Brüsseler Fünfmächtepakt. Das ständige Kommando soll
# ----
#
# Westunion
#  gemeinsam einen „Verteidigungsausschuß der Westunion" bilden.
# ----

# %%
def traiter_texte(text):
    text = text.replace("\n"," ")..replace("\t"," ")
    text = text.replace("Institutin Zürich","Institut in Zürich")
    text = text.replace("desneuen"," des neuen")
    text = text.replace("delas","de las")
    
    return text

# %%
def spacy_format_for_train(data):    
    label_map = {
        'pers':'PER',
        'org':'ORG',
        'loc':'LOC',
    } 
    DATA = []
    for i in range(len(data)):
        values = [(x[1],x[2],label_map.get(x[3],"MISC")) for x in data[i][1:]]
        data[i][0] = data[i][0].replace("\n"," ")
        data[i][0] = data[i][0].replace("\t"," ")
        DATA.append((data[i][0],{"entities":values}))
    return DATA
    
TRAIN_DATA = spacy_format_for_train(train_data)
TRAIN_DATA[0:2]
# Out:
# [('Frankreich.', {'entities': [(0, 10, 'LOC')]}),
#  ("Gesetzgeber. Den 19. Niv. (8. Jän.) warddie Staatskleidung der Sekretär-Redacteurs, derStaatsbothen und Thorwächter für beyde Räthebestimmt. Auf Talot's Vorschlag beschloß manüber den constitutionellen Umkreis, welchen dasgesetzgebende Corps in Zukunft inne haben soll, folgendes: Vom Tage an, da der Rath der 500 in seinen neuen Pallast installirt seyn wird, sind dieäußerlichen Bezirke für beyde Räthe folgendermassen firir: Rarh der Alten: Der Umfang des Nationalpallastes der Alten, in den Tuillerien situirt,enhält gegen Westen die Straße und den Platz desCarrousel bis zum Eintritt in die Straße Nicaise,am Hause Coigny vorbey bis zur Straße des Orties, die Passage de Marigny mit einbegriffen: gegen Suden den Theil des Quai der Gallerien desLouvre's von der Passage de Marigny am rechtenUfer der Seine hinab bis zum Quai der Tuilerien,vom rechten Winkel des Parapets bey der Nationalbrucke bis an den Eingang zum Platze de la Coneorde, die Nationalbrücke bis zum Quai Voltairemit einbegriffen; gegen Osten den Platz de la Concorde in Gemeinschaft mit dem Rathe der 500: gegen Norden den Hof der Orangerie, die Passagedes Feuillans, die Casernen der Grenadiers desgesetzg. Corps mit Zubehörden, den jetzigen Saalder 500 nebst den dazu gehörigen Garten und Gebäuden des Feuillans rc. Rath der 500. Der Umkreis des neuen Nationalpallasies der 500, demAntritt der Revolutionsbrücke gegenüber am Seineufer gelegen, enthält gegen Norden den Quaid'Orsai bis zur Nationalbrücke, den Platz delaConcorde bis zur Orangerie, längs der Gebäude duGardemeuble an den elyseischen Feldern hin biszum Anfange der Straße nach Versailles und demdie Esplanade der Invaliden von der Mauer umden Garten des Raths der 500 scheidet, vom Quai d'Orsai bis zur Universitätsgasse: gegen Süden diese Gasse bis zur Straße Courty; gegen Ostendie Straße Bourgogne bis zum Quai d'Orsai Indiesem Bezirke haben die Saalinspectoren die Polizeyaufsicht allein; doch kann die allgemeine PolizeyDee ",
#   {'entities': [(145, 150, 'PER'),
#     (301, 305, 'ORG'),
#     (427, 431, 'ORG'),
#     (494, 504, 'LOC'),
#     (552, 557, 'LOC'),
#     (595, 601, 'LOC'),
#     (613, 618, 'LOC'),
#     (641, 647, 'LOC'),
#     (664, 671, 'LOC'),
#     (727, 731, 'LOC'),
#     (766, 773, 'LOC'),
#     (804, 809, 'LOC'),
#     (824, 828, 'LOC'),
#     (883, 897, 'LOC'),
#     (921, 927, 'LOC'),
#     (948, 962, 'LOC'),
#     (971, 975, 'LOC'),
#     (1018, 1023, 'LOC'),
#     (1063, 1068, 'ORG'),
#     (1095, 1098, 'LOC'),
#     (1118, 1128, 'LOC'),
#     (1263, 1271, 'LOC'),
#     (1290, 1294, 'ORG'),
#     (1326, 1343, 'LOC'),
#     (1368, 1385, 'LOC'),
#     (1399, 1408, 'LOC'),
#     (1443, 1448, 'LOC'),
#     (1463, 1477, 'LOC'),
#     (1483, 1488, 'LOC'),
#     (1510, 1519, 'LOC'),
#     (1531, 1538, 'LOC'),
#     (1615, 1625, 'LOC'),
#     (1637, 1646, 'LOC'),
#     (1692, 1697, 'ORG'),
#     (1720, 1724, 'LOC'),
#     (1741, 1758, 'LOC'),
#     (1792, 1798, 'LOC'),
#     (1822, 1828, 'LOC'),
#     (1847, 1851, 'LOC')]})]

# %% [markdown]
# ### Training data

# %%
import random
from random import shuffle

def create_model(output_dir,n_iter,TRAIN_DATA):
    nlp = spacy.blank("de")
    
    # get ner pipelines for this model so that we can modify labels
    ner = nlp.create_pipe("ner")
    nlp.add_pipe(ner,last=True)
    
    
    # add labels
    for x,y in TRAIN_DATA:
        for ent in y.get("entities"):
            ner.add_label(ent[2])
        
    # train ner but not others
    pipe_exceptions = set(["ner","trf_wordpiecer","trf_tok2vec"])
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]
    
    with nlp.disable_pipes(*other_pipes) and warnings.catch_warnings():
        warnings.filterwarnings("once",category=UserWarning,module="spacy")
        nlp.begin_training()
        for itn in range(n_iter):
            random.shuffle(TRAIN_DATA)
            losses = {}
            
            # batch up the examples using spaCy's minibatch （speed up for training)
            batches = minibatch(TRAIN_DATA,size=compounding(4.0,32.0,1.001))
            for batch in batches:
                texts,annotations = zip(*batch)
                nlp.update(
                    texts,
                    annotations,
                    drop=0.5,
                    losses=losses,
                )
            print("Losses,",losses)
    
    nlp.to_disk(output_dir)
    
create_model("/home/zijian/ZijianStageNER/Novo_Models/Create/",101,TRAIN_DATA)
# Out:
# Losses, {'ner': 21901.252704107843}
# Losses, {'ner': 5575.999694520142}
# Losses, {'ner': 5339.034751672356}
# Losses, {'ner': 4942.349053597078}
# Losses, {'ner': 4680.652463650156}
# Losses, {'ner': 4660.858366197004}
# Losses, {'ner': 4230.358784696698}
# Losses, {'ner': 4125.303089174908}
# Losses, {'ner': 3803.2817659351276}
# Losses, {'ner': 3809.411183443386}
# Losses, {'ner': 3493.343972873814}
# Losses, {'ner': 3603.288161922901}
# Losses, {'ner': 3420.027510996748}
# Losses, {'ner': 3299.4164641096067}
# Losses, {'ner': 3260.965101563066}
# Losses, {'ner': 3103.8086719831554}
# Losses, {'ner': 3102.76538397102}
# Losses, {'ner': 2945.934652855336}
# Losses, {'ner': 2729.9249583415403}
# Losses, {'ner': 3000.407493845226}
# Losses, {'ner': 2719.1636139813672}
# Losses, {'ner': 2567.027094748677}
# Losses, {'ner': 2579.592337316328}
# Losses, {'ner': 2529.518233144954}
# Losses, {'ner': 2421.1188388117816}
# Losses, {'ner': 2635.7878836361465}
# Losses, {'ner': 2338.217444127071}
# Losses, {'ner': 2348.42946402892}
# Losses, {'ner': 2155.1328641731366}
# Losses, {'ner': 2345.9553509682855}
# Losses, {'ner': 2024.0991188853263}
# Losses, {'ner': 2039.3293948910746}
# Losses, {'ner': 2055.3778795956337}
# Losses, {'ner': 2009.7534191298066}
# Losses, {'ner': 1832.4508412399082}
# Losses, {'ner': 1810.663912651171}
# Losses, {'ner': 2080.882484433571}
# Losses, {'ner': 1713.1587957590987}
# Losses, {'ner': 1670.0312964040268}
# Losses, {'ner': 1650.462245956765}
# Losses, {'ner': 1542.3936202035557}
# Losses, {'ner': 1488.6856058480244}
# Losses, {'ner': 1427.2216885268674}
# Losses, {'ner': 1476.5317635785627}
# Losses, {'ner': 1347.0567960737653}
# Losses, {'ner': 1390.1639847096833}
# Losses, {'ner': 1256.2252624117477}
# Losses, {'ner': 1241.2312478029216}
# Losses, {'ner': 1222.3505397954784}
# Losses, {'ner': 1200.4871193167946}
# Losses, {'ner': 1207.8744752972755}
# Losses, {'ner': 1251.1822981586606}
# Losses, {'ner': 1158.6521507179534}
# Losses, {'ner': 1121.4706864444001}
# Losses, {'ner': 1058.265087748715}
# Losses, {'ner': 1069.2318073959277}
# Losses, {'ner': 1039.7791164363348}
# Losses, {'ner': 1079.2166871329468}
# Losses, {'ner': 1129.4254070741954}
# Losses, {'ner': 1091.5723116127936}
# Losses, {'ner': 957.8638754336364}
# Losses, {'ner': 960.074616814145}
# Losses, {'ner': 879.3361853242712}
# Losses, {'ner': 890.8429293587451}
# Losses, {'ner': 913.7527836924485}
# Losses, {'ner': 863.4118464010517}
# Losses, {'ner': 798.9957643652394}
# Losses, {'ner': 854.5483532262182}
# Losses, {'ner': 835.6574901357717}
# Losses, {'ner': 776.121276619108}
# Losses, {'ner': 766.2581222343598}
# Losses, {'ner': 737.8265279727364}
# Losses, {'ner': 772.9373772324789}
# Losses, {'ner': 752.987630528976}
# Losses, {'ner': 715.3303961047851}
# Losses, {'ner': 662.7815802491539}
# Losses, {'ner': 700.236708130139}
# Losses, {'ner': 752.1726764748256}
# Losses, {'ner': 710.7095921385434}
# Losses, {'ner': 648.7923905239717}
# Losses, {'ner': 705.7099434265696}
# Losses, {'ner': 681.5635727503457}
# Losses, {'ner': 702.0967778921065}
# Losses, {'ner': 819.0567729172928}
# Losses, {'ner': 766.9633737528316}
# Losses, {'ner': 647.647320847943}
# Losses, {'ner': 680.6306494977144}
# Losses, {'ner': 648.7753535348479}
# Losses, {'ner': 794.7536572974859}
# Losses, {'ner': 826.1138640629334}
# Losses, {'ner': 657.5533676546604}
# Losses, {'ner': 608.7915463489768}
# Losses, {'ner': 602.6585624665399}
# Losses, {'ner': 623.0189360643386}
# Losses, {'ner': 581.759848145101}
# Losses, {'ner': 546.3832669426423}
# Losses, {'ner': 565.9627530247599}
# Losses, {'ner': 569.0821737392862}
# Losses, {'ner': 533.8109390591317}
# Losses, {'ner': 540.3698442758587}
# Losses, {'ner': 524.9270747152497}

# %%
def training(TRAIN_DATA,model,output_dir,n_iter):
    nlp = nlp_de1
    
    # get ner pipelines for this model so that we can modify labels
    ner = nlp.get_pipe("ner")
    
    # add labels
    for x,y in TRAIN_DATA:
        for ent in y.get("entities"):
            ner.add_label(ent[2])
        
    # train ner but not others
    pipe_exceptions = set(["ner","trf_wordpiecer","trf_tok2vec"])
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]
    
    with nlp.disable_pipes(*other_pipes) and warnings.catch_warnings():
        warnings.filterwarnings("once",category=UserWarning,module="spacy")
        for itn in range(n_iter):
            random.shuffle(TRAIN_DATA)
            losses = {}
            
            # batch up the examples using spaCy's minibatch （speed up for training)
            batches = minibatch(TRAIN_DATA,size=compounding(4.0,32.0,1.001))
            for batch in batches:
                texts,annotations = zip(*batch)
                nlp.update(
                    texts,
                    annotations,
                    drop=0.5,
                    losses=losses,
                )
            print("Losses,",losses)
    
    nlp.to_disk(output_dir)
    
training(TRAIN_DATA,"de_core_news_sm","/home/zijian/ZijianStageNER/RetrainModels/",100)

# %% [markdown]
# ### Test this new model with dev data

# %% [markdown]
# ### Gold

# %%
import json
with open("novo_dev_de.json",'r',encoding="utf-8")as f:
    dev = json.load(f)

DEV_DATA = spacy_format_for_train(dev)
for i in range(len(DEV_DATA)):
    DEV_DATA[i] = (DEV_DATA[i][0],DEV_DATA[i][1]["entities"])

# %% [markdown]
# ### Test

# %%
from spacy.scorer import Scorer
from spacy.gold import GoldParse
from spacy.scorer import Scorer

def evaluate(ner_model,data):
    scorer = Scorer()
    for text,annot in data:
        doc_gold_text = ner_model.make_doc(text)
        gold = GoldParse(doc_gold_text,entities=annot)
        pred_value = ner_model(text)
        scorer.score(pred_value,gold)
    return scorer.scores


#path = "/home/zijian/ZijianStageNER/Novo_Models/Create"
#nlp2 = spacy.load(path)
#results = evaluate(nlp2,DEV_DATA)

# %% [markdown]
# ### Train by updating the model in spacy de_core_web_sm

# %%
def training(TRAIN_DATA,model,output_dir,n_iter):
    nlp = nlp_de1
    
    # get ner pipelines for this model so that we can modify labels
    ner = nlp.get_pipe("ner")
    
    # add labels
    for x,y in TRAIN_DATA:
        for ent in y.get("entities"):
            ner.add_label(ent[2])
        
    # train ner but not others
    pipe_exceptions = set(["ner","trf_wordpiecer","trf_tok2vec"])
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]
    
    with nlp.disable_pipes(*other_pipes) and warnings.catch_warnings():
        warnings.filterwarnings("once",category=UserWarning,module="spacy")
        for itn in range(n_iter):
            random.shuffle(TRAIN_DATA)
            losses = {}
            
            # batch up the examples using spaCy's minibatch （speed up for training)
            batches = minibatch(TRAIN_DATA,size=compounding(4.0,32.0,1.001))
            for batch in batches:
                texts,annotations = zip(*batch)
                nlp.update(
                    texts,
                    annotations,
                    drop=0.5,
                    losses=losses,
                )
            print("Losses,",losses)
    
    nlp.to_disk(output_dir)
    
training(TRAIN_DATA,"de_core_news_sm","/home/zijian/ZijianStageNER/RetrainModels/",100)

# %%
path = "/home/zijian/ZijianStageNER/RetrainModels/"
nlp2 = spacy.load(path)
results2 = evaluate(nlp2,DEV_DATA)

res = pd.DataFrame({"precison":[results['ents_p'],results2['ents_p']],"recall":[results['ents_r'],results2['ents_r']],"f1":[results['ents_f'],results2['ents_f']]},index=["Model only with my train_data","Model with data TigerCorpus and my train data"])
res
# Out:
#                                                 precison     recall         f1
# Model only with my train_data                  64.814815  53.030303  58.333333
# Model with data TigerCorpus and my train data  70.909091  59.090909  64.462810

# %% [markdown]
# ### So What is the difference? Model 1 could detect what? Model 2 could detect what?

# %%
Train_Data_Model = spacy.load("ModelsRetrained/Novo_Models/Create/")
SM_plus_Train_DATA_Model = spacy.load("ModelsRetrained/Novo_Models/UpdateModel1/RetrainModels/")

# %%
def context(text,i,j):
    left,right = i,j
    count = 0
    if left > 0:
        while count < 5 and left > 0:
            left-=1
            if text[left]==' ':
                count+=1
    count = 0
    while count < 5 and right+1 < len(text):
        right += 1
        if text[right]==' ':
            count += 1
    return text[left:right]

def consulter(model,dev):
    results = []
    for i in range(len(dev)):
        doc = model(dev[i][0])
        tmp = []
        for ent in doc.ents:
            tmp.append([ent.text,ent.start_char,ent.end_char,ent.label_,context(dev[i][0],ent.start_char,ent.end_char)])
        results.append(tmp) 
    return results

# Model with train_de.json :
res1 = consulter(Train_Data_Model,dev)

# Model with train_de.json + sm:
res2 = consulter(SM_plus_Train_DATA_Model,dev)

print(len(res1)," ",len(res2))
# Out:
# 40   40

# %%
def correction():
    correction = []
    for i in range(len(dev)):
        text = dev[i][0]
        tmp = []
        for x in dev[i][1:]:
            tmp.append([x[0],x[1],x[2],x[3],context(text,x[1],x[2])])
        correction.append(tmp[:])
    return correction
correction = correction()
print(correction[1])
# Out:
# [['Petersburg', 11, 21, 'LOC', '(Condeer.] Petersburg den 18. Dec. Se.russisch- kaiserl.'], ['Prinzen', 76, 83, 'PER', ' kaiserl. Majestät haben dem Prinzen vonCondé bey dessen Ankunft in'], ['Petersburg', 115, 125, 'LOC', ' bey dessen Ankunft in Petersburg den St.Andreas-Orden u. den Maltheser'], ['Polen', 179, 184, 'LOC', ' den Maltheser Ritterorden in Polen zu ertheilen, und ihn mit'], ['Petersburg', 256, 266, 'LOC', ' prächtigen,völlig meublirten Palais in Petersburg zu beschenken geruhet. Das aus'], ['Prinzen', 362, 369, 'PER', ' Kavallerie-Regimentern bestehende Corps des Prinzen vonCondé, welches in kaiserliche Dienste'], ['Wladimir', 440, 448, 'LOC', ' genommenworden, ist nun nach Wladimir, Luzk und Kowelin Quartier'], ['Luzk', 450, 454, 'LOC', ' ist nun nach Wladimir, Luzk und Kowelin Quartier verlegt. Das'], ['Kowelin', 459, 466, 'LOC', ' nach Wladimir, Luzk und Kowelin Quartier verlegt. Das ganze Corps'], ['Prinzen', 538, 545, 'PER', ' wird unterbestandiger Inspection des Prinzen von Condéstehen. Se. kaiserl. Majestät'], ['Duc', 647, 650, 'PER', ' desadelichen Infanterie-Regiments, und den Duc deBerry zum Chef des adelichen']]

# %%
print(res2[1])
print(correction[1])
# Out:
# [['Condeer', 1, 8, 'LOC', '(Condeer.] Petersburg den 18. Dec.'], ['Petersburg', 11, 21, 'LOC', '(Condeer.] Petersburg den 18. Dec. Se.russisch- kaiserl.'], ['Petersburg', 115, 125, 'LOC', ' bey dessen Ankunft in Petersburg den St.Andreas-Orden u. den Maltheser'], ['St', 130, 132, 'LOC', ' Ankunft in Petersburg den St.Andreas-Orden u. den Maltheser Ritterorden'], ['Polen', 179, 184, 'LOC', ' den Maltheser Ritterorden in Polen zu ertheilen, und ihn mit'], ['Petersburg', 256, 266, 'LOC', ' prächtigen,völlig meublirten Palais in Petersburg zu beschenken geruhet. Das aus'], ['Wladimir', 440, 448, 'LOC', ' genommenworden, ist nun nach Wladimir, Luzk und Kowelin Quartier'], ['Luzk', 450, 454, 'LOC', ' ist nun nach Wladimir, Luzk und Kowelin Quartier verlegt. Das'], ['Kowelin', 459, 466, 'PER but correct : (LOC) but correct : (LOC) but correct : (LOC) but correct : (LOC) but correct : (LOC) but correct : (LOC) but correct : (LOC) but correct : (LOC) but correct : (LOC)', ' nach Wladimir, Luzk und Kowelin Quartier verlegt. Das ganze Corps'], ['Se', 563, 565, 'PER', ' des Prinzen von Condéstehen. Se. kaiserl. Majestät haben ihn'], ['Duc', 647, 650, 'LOC but correct : (PER) but correct : (PER) but correct : (PER) but correct : (PER) but correct : (PER) but correct : (PER) but correct : (PER) but correct : (PER) but correct : (PER)', ' desadelichen Infanterie-Regiments, und den Duc deBerry zum Chef des adelichen']]
# [['Petersburg', 11, 21, 'LOC', '(Condeer.] Petersburg den 18. Dec. Se.russisch- kaiserl.'], ['Prinzen', 76, 83, 'PER', ' kaiserl. Majestät haben dem Prinzen vonCondé bey dessen Ankunft in'], ['Petersburg', 115, 125, 'LOC', ' bey dessen Ankunft in Petersburg den St.Andreas-Orden u. den Maltheser'], ['Polen', 179, 184, 'LOC', ' den Maltheser Ritterorden in Polen zu ertheilen, und ihn mit'], ['Petersburg', 256, 266, 'LOC', ' prächtigen,völlig meublirten Palais in Petersburg zu beschenken geruhet. Das aus'], ['Prinzen', 362, 369, 'PER', ' Kavallerie-Regimentern bestehende Corps des Prinzen vonCondé, welches in kaiserliche Dienste'], ['Wladimir', 440, 448, 'LOC', ' genommenworden, ist nun nach Wladimir, Luzk und Kowelin Quartier'], ['Luzk', 450, 454, 'LOC', ' ist nun nach Wladimir, Luzk und Kowelin Quartier verlegt. Das'], ['Kowelin', 459, 466, 'LOC', ' nach Wladimir, Luzk und Kowelin Quartier verlegt. Das ganze Corps'], ['Prinzen', 538, 545, 'PER', ' wird unterbestandiger Inspection des Prinzen von Condéstehen. Se. kaiserl. Majestät'], ['Duc', 647, 650, 'PER', ' desadelichen Infanterie-Regiments, und den Duc deBerry zum Chef des adelichen']]

# %%
for x in res2[1]:
    print(x)
print()
for x in correction[1]:
    print(x)
# Out:
# ['Condeer', 1, 8, 'LOC', '(Condeer.] Petersburg den 18. Dec.']
# ['Petersburg', 11, 21, 'LOC', '(Condeer.] Petersburg den 18. Dec. Se.russisch- kaiserl.']
# ['Petersburg', 115, 125, 'LOC', ' bey dessen Ankunft in Petersburg den St.Andreas-Orden u. den Maltheser']
# ['St', 130, 132, 'LOC', ' Ankunft in Petersburg den St.Andreas-Orden u. den Maltheser Ritterorden']
# ['Polen', 179, 184, 'LOC', ' den Maltheser Ritterorden in Polen zu ertheilen, und ihn mit']
# ['Petersburg', 256, 266, 'LOC', ' prächtigen,völlig meublirten Palais in Petersburg zu beschenken geruhet. Das aus']
# ['Wladimir', 440, 448, 'LOC', ' genommenworden, ist nun nach Wladimir, Luzk und Kowelin Quartier']
# ['Luzk', 450, 454, 'LOC', ' ist nun nach Wladimir, Luzk und Kowelin Quartier verlegt. Das']
# ['Kowelin', 459, 466, 'PER but correct : (LOC) but correct : (LOC) but correct : (LOC) but correct : (LOC) but correct : (LOC) but correct : (LOC) but correct : (LOC) but correct : (LOC) but correct : (LOC)', ' nach Wladimir, Luzk und Kowelin Quartier verlegt. Das ganze Corps']
# ['Se', 563, 565, 'PER', ' des Prinzen von Condéstehen. Se. kaiserl. Majestät haben ihn']
# ['Duc', 647, 650, 'LOC but correct : (PER) but correct : (PER) but correct : (PER) but correct : (PER) but correct : (PER) but correct : (PER) but correct : (PER) but correct : (PER) but correct : (PER)', ' desadelichen Infanterie-Regiments, und den Duc deBerry zum Chef des adelichen']
#
# ['Petersburg', 11, 21, 'LOC', '(Condeer.] Petersburg den 18. Dec. Se.russisch- kaiserl.']
# ['Prinzen', 76, 83, 'PER', ' kaiserl. Majestät haben dem Prinzen vonCondé bey dessen Ankunft in']
# ['Petersburg', 115, 125, 'LOC', ' bey dessen Ankunft in Petersburg den St.Andreas-Orden u. den Maltheser']
# ['Polen', 179, 184, 'LOC', ' den Maltheser Ritterorden in Polen zu ertheilen, und ihn mit']
# ['Petersburg', 256, 266, 'LOC', ' prächtigen,völlig meublirten Palais in Petersburg zu beschenken geruhet. Das aus']
# ['Prinzen', 362, 369, 'PER', ' Kavallerie-Regimentern bestehende Corps des Prinzen vonCondé, welches in kaiserliche Dienste']
# ['Wladimir', 440, 448, 'LOC', ' genommenworden, ist nun nach Wladimir, Luzk und Kowelin Quartier']
# ['Luzk', 450, 454, 'LOC', ' ist nun nach Wladimir, Luzk und Kowelin Quartier verlegt. Das']
# ['Kowelin', 459, 466, 'LOC', ' nach Wladimir, Luzk und Kowelin Quartier verlegt. Das ganze Corps']
# ['Prinzen', 538, 545, 'PER', ' wird unterbestandiger Inspection des Prinzen von Condéstehen. Se. kaiserl. Majestät']
# ['Duc', 647, 650, 'PER', ' desadelichen Infanterie-Regiments, und den Duc deBerry zum Chef des adelichen']

# %%
def evaluate(res,correction):        
    VP = []
    FP = []
    VN = [] 
    for x in range(len(res)):
        a = res[x]
        b = correction[x]
        i,j = 0,0
        while i<len(a) and j<len(b):
            l1,r1 = a[i][1],a[i][2]
            l2,r2 = b[j][1],b[j][2]
            print("modèle detection : ",a[i])
            print("références : ",b[j])
            print()
            if l1>r2:
                VN.append(b[j])
                j+=1
            elif r1 < l2:
                FP.append(a[i])
                i+=1
            elif l1==l2 and r1==r2:
                if a[i][3]!=b[j][3]:
                    a[i][3] += " but correct : ({})".format(b[j][3])
                    FP.append(a[i])
                else:
                    VP.append(a[i])
                i+=1
                j+=1
            else:
                if a[i][0] in b[j][4]:
                    if a[i][3]!=b[j][3]:
                        a[i][3] += " but correct : ({})".format(b[j][3])
                        FP.append(a[i])
                    else:
                        VP.append(a[i])
                else:
                    FP.append(a[i])
                i+=1
                j+=1  
            print("Vrai positif : ",len(VP)," Faux positif ： ",len(FP)," Faux Négatif ： ",len(VN))
            print("--------")
            print()
        while i<len(a):
            FP.append(a[i])
            i+=1
        while j<len(b):
            VN.append(b[j])
            j+=1
    return [VP,FP,VN]

a = [[['Condeer', 1, 8, 'LOC', '(Condeer.] Petersburg den 18. Dec.']]]
b = [[['Petersburg', 2, 9, 'LOC', '(Condeer.] Petersburg den 18. Dec. Se.russisch- kaiserl.']]]

evaluate(a,b)
# Out:
# modèle detection :  ['Condeer', 1, 8, 'LOC', '(Condeer.] Petersburg den 18. Dec.']
# références :  ['Petersburg', 2, 9, 'LOC', '(Condeer.] Petersburg den 18. Dec. Se.russisch- kaiserl.']
#
# Vrai positif :  1  Faux positif ：  0  Faux Négatif ：  0
# --------
# [[['Condeer', 1, 8, 'LOC', '(Condeer.] Petersburg den 18. Dec.']], [], []]

# %%
result1 = evaluate(res1,correction)
result2 = evaluate(res2,correction)

# %%
import pandas as pd

d1 = pd.DataFrame({"NER":[x[0] for x in result1[1]],"Type":[x[3] for x in result1[1]],"Context":[x[4] for x in result1[1]]},index = [x for x in range(1,len(result1[1])+1)])
d2 = pd.DataFrame({"NER":[x[0] for x in result1[2]],"Type":[x[3] for x in result1[2]],"Context":[x[4] for x in result1[2]]},index = [x for x in range(1,len(result1[2])+1)])

d3 = pd.DataFrame({"NER":[x[0] for x in result2[1]],"Type":[x[3] for x in result2[1]],"Context":[x[4] for x in result2[1]]},index = [x for x in range(1,len(result2[1])+1)])
d4 = pd.DataFrame({"NER":[x[0] for x in result2[2]],"Type":[x[3] for x in result2[2]],"Context":[x[4] for x in result2[2]]},index = [x for x in range(1,len(result2[2])+1)])


html_string1 = '''
<html>
  <meta charset="UTF-8"></meta>
  <head><title>Faux Postif</title></head>
  <body>
    {table}
  </body>
</html>.
'''

html_string2 = '''
<html>
  <meta charset="UTF-8"></meta>
  <head><title>Vrai Négatif</title></head>
  <body>
    {table}
  </body>
</html>.
'''

with open("résultat/Model only with train/Faux Positif.html","w",encoding='utf-8') as f:
    f.write(html_string1.format(table=d1.to_html()))
with open("résultat/Model only with train/Vrai Négatif.html","w",encoding='utf-8') as f:
    f.write(html_string2.format(table=d2.to_html()))
with open("résultat/Model with train + Spacy Model/Faux Positif.html","w",encoding='utf-8') as f:
    f.write(html_string1.format(table=d3.to_html()))
with open("résultat/Model with train + Spacy Model/Vrai Négatif.html","w",encoding='utf-8') as f:
    f.write(html_string2.format(table=d4.to_html()))

# %% [markdown]
# ### Statistics for the results
#
#
# #### Type of NER

# %%
def stats(result2,typeLabel):
    total = []
    trouvé = list(filter(lambda x:x[3]==typeLabel,result2[0]))
    incorrect = list(filter(lambda x:x[3]==typeLabel,result2[1]))
    non_trouvé = list(filter(lambda x:x[3]==typeLabel,result2[2]))
    total+=(trouvé+incorrect+non_trouvé)
    p = round(len(trouvé)/(len(trouvé)+len(incorrect))*100,3)
    r = round(len(trouvé)/(len(non_trouvé)+len(trouvé))*100,3)
    if p+r!=0:
        f = round(2*p*r/(p+r),3)
    else:
        f = 0.0
    return [p,r,f]

# %% [markdown]
# ##### 1. LOC

# %%
loc = stats(result2,"LOC")
print(loc)
# Out:
# [76.432, 55.878, 64.558]

# %% [markdown]
# ###### 2. PERS

# %%
pers = stats(result2,"PER")
print(pers)
# Out:
# [56.727, 40.31, 47.13]

# %% [markdown]
# ###### 3. Orgs

# %%
orgs = stats(result2,"ORG")
print(orgs)
# Out:
# [77.083, 25.17, 37.949]

# %% [markdown]
# ##### 4. MISC

# %%
misc = stats(result2,"MISC")
print(misc)
# Out:
# [61.702, 23.77, 34.319]

# %%
import pandas as pd
res = pd.DataFrame({"Précision":[loc[0],pers[0],orgs[0],misc[0]],"Rappel":[loc[1],pers[1],orgs[1],misc[1]],'F-Mesure':[loc[2],pers[2],orgs[2],misc[2]]},index = ["Location","Person","Organisation","Miscellaneous entities"])
res
# Out:
#                         Précision  Rappel  F-Mesure
# Location                   76.432  55.878    64.558
# Person                     56.727  40.310    47.130
# Organisation               77.083  25.170    37.949
# Miscellaneous entities     61.702  23.770    34.319

# %%
html_string1 = '''
<html>
  <meta charset="UTF-8"></meta>
  <head><title>Faux Postif</title></head>
  <body>
    {table}
  </body>
</html>.
'''

html_string2 = '''
<html>
  <meta charset="UTF-8"></meta>
  <head><title>Vrai Négatif</title></head>
  <body>
    {table}
  </body>
</html>.
'''
with open("résultat/Model with train + Spacy Model/Chaque_type.html","w",encoding='utf-8') as f:
    f.write(html_string1.format(table=res.to_html()))

# %% [markdown]
# ### Observe every NER not finded or finded but not correct
#
# ##### Incorrect

# %%
import collections
from collections import Counter
fp = dict(Counter([x[0] for x in result2[1]]))
fp = sorted(fp.items(),key=lambda x:x[1],reverse=True)
print(fp)
# Out:
# [('Zürich', 4), ('von', 3), ('Paris', 3), ('Preußen', 3), ('Nationalrath', 3), ('Baden', 3), ('Bundesrath', 3), ('Sängervereins', 3), ('Schweiz', 3), ('Ferdinand', 3), ('Se', 2), ('Lord', 2), ('vom', 2), ('Asselt', 2), ('am', 2), ('Kompagnien', 2), ('Bucharest', 2), ('Baron', 2), ('Jedermann', 2), ('Nationalgarde', 2), ('Herren', 2), ('seit', 2), ('Papier', 2), ('Sündfluth', 2), ('XVI', 2), ('Noven', 2), ('Graf', 2), ('Bürgerschaft', 2), ('Chöre', 2), ('Händler', 2), ('Basel', 2), ('Nokraschi', 2), ('Ministeriums', 2), ('Condeer', 1), ('St', 1), ('Kowelin', 1), ('Duc', 1), ('Königreichs', 1), ('FortsetzungIhrer', 1), ('Gefahrenund', 1), ('Unglük', 1), ('Sinclair', 1), ('consolidirten3', 1), ('Landein', 1), ('Courier', 1), ('Belgische', 1), ('vereinigten', 1), ('Sittard', 1), ('Lüttich', 1), ('Betagerungsstand', 1), ('Roumiroir', 1), ('Kühnheitgehabt', 1), ('Löwen', 1), ('Batavische', 1), ('Schuldenscheine', 1), ('Sevilla', 1), ('Hauptstraßenach', 1), ('Saragossa', 1), ('Gegenwart', 1), ('Derzirks', 1), ('Mury', 1), ('Cantons', 1), ('Anno1804', 1), ('Beinwyl', 1), ('Höfe', 1), ('Negociation', 1), ('Broglie', 1), ('Pairs', 1), ('Frankreich', 1), ('Archipelagus', 1), ('Vorschein', 1), ('Ungeachtetsämmtliche', 1), ('Ernst', 1), ('Dominik', 1), ('Landammann', 1), ('nicht4', 1), ('Spitzeeiner', 1), ('BesilsAghalari', 1), ('Besils', 1), ('Stroganoff', 1), ('Jakob', 1), ('im', 1), ('Deutschland', 1), ('Himmelfahrt', 1), ('Roms', 1), ('Tilff', 1), ('Longrée', 1), ('Gewissensangst', 1), ('Pest', 1), ('Zollvereinsstaatenzu', 1), ('unterm', 1), ('König', 1), ('Anklagezustand', 1), ('Königkann', 1), ('Schlägereien', 1), ('Wortwechsel', 1), ('Ställen', 1), ('Straße', 1), ('Einmuth', 1), ('Ständerath', 1), ('RegierungsrathMüller', 1), ('Bezirksgerichtspräsident', 1), ('Eisenbahnwesens', 1), ('Baselland', 1), ('Meier', 1), ('Heckers', 1), ('Zugedurch', 1), ('Massennirgends', 1), ('Nachbarn', 1), ('Landwehrmann', 1), ('VizePräsidenten', 1), ('Adolf', 1), ('Schlangenthores', 1), ('Cadmus', 1), ('Nebukadnezar', 1), ('Christi', 1), ('Granada', 1), ('Leon', 1), ('Burgos', 1), ('Zaragoza', 1), ('Spanien', 1), ('Madrids', 1), ('Madrid', 1), ('Ostschweiz', 1), ('Revue', 1), ('Wennein', 1), ('Mitgabe', 1), ('Kircheund', 1), ('Fernbleibenden', 1), ('Bundesunterstützungen', 1), ('Bayern', 1), ('ZürichEugen', 1), ('Lyonais', 1), ('Kanton', 1), ('Rudolf', 1), ('Gemeinde', 1), ('Kantons', 1), ('Bogno', 1), ('Crana', 1), ('Naturalien', 1), ('Fahrpreisemit', 1), ('Chor', 1), ('Tannhäuser', 1), ('Faßbänders', 1), ('Musikdirektor', 1), ('Programmdie', 1), ('Elisabeth', 1), ('Orelli', 1), ('LiederkranzAußersihl-Zürich', 1), ('Blumenthal', 1), ('Kadelburg', 1), ('Verdi', 1), ('Cavalleria', 1), ('Störenfried', 1), ('Stadt', 1), ('Alter', 1), ('Schweizerische', 1), ('Woermann', 1), ('Vortagenan', 1), ('Havas', 1), ('Luxemburg', 1), ('Major', 1), ('Henry', 1), ('Talaat', 1), ('Volkan', 1), ('Ritter', 1), ('Herdwar', 1), ('Bravo', 1), ('Neugier', 1), ('unkundigen', 1), ('Herrn', 1), ('Rathausdurch', 1), ('bürgerlichen', 1), ('ZürcherBürgerschaft', 1), ('Zürichs', 1), ('Informationsorgau', 1), ('Zubloßem', 1), ('MancherSchweizer', 1), ('Vergeblich', 1), ('Oltner', 1), ('OltenerKomitee', 1), ('Kasino', 1), ('Protestgastspielenein', 1), ('Sängerfestin', 1), ('A.Am', 1), ('Schweizervolk', 1), ('Eidgenössischen', 1), ('Ligia', 1), ('Kategorien', 1), ('IV', 1), ('Anreiz', 1), ('Männerchorsaches', 1), ('Erwin', 1), ('Männerchorwesen', 1), ('Begrüßungskonzerten', 1), ('BäckersProduzent', 1), ('Migros', 1), ('gehen4', 1), ('Originaldokumenten', 1), ('Anwendungaller', 1), ('Scharen', 1), ('Juwelenräubers', 1), ('Goumoéns', 1), ('Société', 1), ('Reserent', 1), ('Robert', 1), ('Gelatinefäden', 1), ('beschrieb', 1), ('Viscoseversahren', 1), ('Lumpen', 1), ('Baumvoll', 1), ('Besançon', 1), ('Unternehmenfabrizierten', 1), ('Givet', 1), ('Cross', 1), ('Bevan', 1), ('Beadle', 1), ('Vereinigten', 1), ('Gualino', 1), ('Dreysus', 1), ('Rhodiaseta', 1), ('Celanaise', 1), ('British', 1), ...

# %% [markdown]
# ##### Non_trouvé

# %%
import collections
from collections import Counter
fn = dict(Counter([x[0] for x in result2[2]]))
fn = sorted(fn.items(),key=lambda x:x[1],reverse=True)
print(fn)
# Out:
# [('Hr', 22), ('Hrn', 9), ('Zürich', 9), ('Dr', 9), ('von', 8), ('Guyer', 6), ('Kirchgemeinde', 6), ('St', 5), ('Schweiz', 5), ('1937', 5), ('Deutschland', 4), ('Prof', 4), ('im', 4), ('Bürgliterrasse', 4), ('Bundesgericht', 4), ('Küßnacht', 4), ('Volksrecht', 4), ('Prinzen', 3), ('Havre', 3), ('alt', 3), ('Solothurner', 3), ('Oesterreich', 3), ('A', 3), ('L', 3), ('Köln', 3), ('Wafd', 3), ('Nokraschi', 3), ('junge', 2), ('das', 2), ('Gerona', 2), ('Wohlen', 2), ('Bundeszeitung', 2), ('Journal', 2), ('New', 2), ('hannoversche', 2), ('Preußenverein', 2), ('Berlin', 2), ('Winterthur', 2), ('Liestal', 2), ('Basellandschaftliche', 2), ('Wallis', 2), ('Oberrichter', 2), ('Clement', 2), ('Madrid', 2), ('dem', 2), ('Toledo', 2), ('Andrassy', 2), ('Freiburg', 2), ('Lausanner', 2), ('Bundesversammlung', 2), ('Kellersberger', 2), ('KantonsZürich', 2), ('Gobat', 2), ('am', 2), ('Frey', 2), ('Schweizerische', 2), ('Interlaken', 2), ('vom', 2), ('Lauterbrunnen', 2), ('Männerchor', 2), ('Bürgerlichen', 2), ('Eidgenössischen', 2), ('Lausanne', 2), ('Leman', 2), ('welsche', 2), ('als', 2), ('Bäckermeisterverband', 2), ('Emile', 2), ('Chardonnet', 2), ('Chardonnetscide', 2), ('Deutsche', 2), ('1923', 2), ('1936', 2), ('Berlins', 2), ('Aexypten', 2), ('Watd', 2), ('Neumarkte', 2), ('K', 2), ('Westunion', 2), ('Lords', 1), ('Craven', 1), ('Nitter', 1), ('For', 1), ('Pitt', 1), ('Adm', 1), ('NelsonsBelohnung', 1), ('ben', 1), ('Bompartschen', 1), ('Abukir', 1), ('Gibraltar', 1), ('Bengalen', 1), ('neuen', 1), ('Tippo', 1), ('Wesel', 1), ('Aachen', 1), ('Mosel', 1), ('Leyden', 1), ('Leydner', 1), ('ehemalige', 1), ('Löwenunter', 1), ('Munizipal', 1), ('bis', 1), ('Trochtelfingen', 1), ('Hohenzöllern', 1), ('Johannes', 1), ('Gemeine', 1), ('Christenthum', 1), ('Wiener', 1), ('General', 1), ('Mengibar', 1), ('Marquis', 1), ('Villanueva', 1), ('Coupigny', 1), ('Andujar', 1), ('Arragonische', 1), ('Saragossa', 1), ('Villa', 1), ('Obergenerals', 1), ('Generale', 1), ('Goubot', 1), ('Düponts', 1), ('Detuwol', 1), ('vorgestellt', 1), ('Gemeinden', 1), ('Summeri', 1), ('Grod', 1), ('Frankteich', 1), ('Herzogs', 1), ('H', 1), ('Bayern', 1), ('Deutschlandzurückkehren', 1), ('Wales', 1), ('Pesaro', 1), ('Hannoverschreiten', 1), ('Diario', 1), ('geflüchteten', 1), ('Moldau', 1), ('Apsilanti', 1), ('treulose', 1), ('Rußland', 1), ('Besils', 1), ('Uri', 1), ('Kloster', 1), ('Wettingen', 1), ('Neuenburg', 1), ('Mairie', 1), ('P', 1), ('Die', 1), ('nördliche', 1), ('London', 1), ('Liverpool', 1), ('Herzog', 1), ('Fürstenthums', 1), ('Göttingen', 1), ('Kölner', 1), ('heint', 1), ('Belgien', 1), ('Bürgermeister', 1), ('Herrde', 1), ('Dresden', 1), ('Europäischen', 1), ('1819', 1), ('Aarauerschienen', 1), ('Iratien', 1), ('Gott', 1), ('demokratischen', 1), ('Fr', 1), ('Demokratenverein', 1), ('RepublikanerEdgar', 1), ('Unter', 1), ('Präsidenten', 1), ('austretenden', 1), ('Stadtpräsident', 1), ('Oberstl', 1), ('Blank-Arbenz', 1), ('Regierungsrath', 1), ('Nr', 1), ('Winterthurer', 1), ('Landboten', 1), ('Landbote', 1), ('Berner', 1), ('Zürcherschen', 1), ('Genfer', 1), ('N', 1), ('Ermatingen', 1), ('Gazette', 1), ('Trogenwald', 1), ('Turtmanthaleine', 1), ('DorfLuc', 1), ('Einsischthal', 1), ('Schneider', 1), ('Krebser', 1), ('Stadtverein', 1), ('HH', 1), ('Strehler', 1), ('Georgia', 1), ('kluge', 1), ('Württemberg', 1), ('Schoch', 1), ('Frei', 1), ('RabrlihDaß', 1), ('Escorial', 1), ('Adams', 1), ('Stadt', 1), ('Cordoba', 1), ('zu', 1), ('einheitlichen', 1), ('Sevilla', 1), ('Granadadas', 1), ('seit', 1), ('Madrider', 1), ('Dänemarkund', 1), ('Deutschlandseit', 1), ('Bismarck', 1), ("Bismarck'schen", 1), ('Andrafsy', 1), ('Centralasien', 1), ('Afghanistan', 1), ('Indien', 1), ('Rußlandsaus', 1), ('konservativ', 1), ('Vaterland', 1), ('1875', 1), ('Liberte', 1), ('AdolfGuyer', 1), ('Engeaufheben', 1), ('Bundesverfassung', 1), ('Kantons', 1), ('Enge', 1), ('Expropriaten', 1), ('protestantischen', 1), ('Gobats', 1), ('eidgenössischen', 1), ('Speichergasse', 1), ('Bundes ...

# %%
import pandas as pd
tf_incorrect = pd.DataFrame({"NER":[x[0] for x in fp],"Frequecy":[x[1] for x in fp]})
tf_non_trouvé = pd.DataFrame({"NER":[x[0] for x in fn],"Frequency":[x[1] for x in fn]})


html_string1 = '''
<html>
  <meta charset="UTF-8"></meta>
  <head><title>Term Frequency for incorrect NER</title></head>
  <body>
    {table}
  </body>
</html>.
'''

html_string2 = '''
<html>
  <meta charset="UTF-8"></meta>
  <head><title>Term Frequency for non correct NER</title></head>
  <body>
    {table}
  </body>
</html>.
'''
with open("résultat/Model with train + Spacy Model/tfFP.html","w",encoding='utf-8') as f:
    f.write(html_string1.format(table=tf_incorrect.to_html()))

with open("résultat/Model with train + Spacy Model/tfFN.html","w",encoding='utf-8') as f:
    f.write(html_string1.format(table=tf_non_trouvé.to_html()))

# %%
"Prinzen" in set([x[0] for x in result2[0]])
# Out:
# False

# %%
"Zürich" in set([x[0] for x in result2[0]])
# Out:
# True

# %% [markdown]
# ### Zürich exists both in VP and Faux Negatif

# %%
Zürich_vp = list(filter(lambda x:x[0]=="Zürich",result2[0]))
Zürich_fp = list(filter(lambda x:x[0]=="Zürich",result2[1]))
Zürich_fn = list(filter(lambda x:x[0]=="Zürich",result2[2]))
print(Zürich_vp[0],len(Zürich_vp))
print(Zürich_fp[0],len(Zürich_fp))
print(Zürich_fn[0],len(Zürich_fn))
# Out:
# ['Zürich', 3, 9, 'LOC', 'In Zürich starb am 2. April Hr.'] 30
# ['Zürich', 785, 791, 'LOC', ' gesetzt wurden.— Der Stadtverein Zürich hat in seiner Versammlung vom'] 4
# ['Zürich', 2111, 2117, 'LOC', ' in Zürich, Nationalrath Fierz inZürich, Oberstl. v. Muralt in'] 9

# %%
html_string = '''
<html>
  <meta charset="UTF-8"></meta>
  <head><title>Zürich</title></head>
  <body>
    {table}
  </body>
</html>.
'''
tmp1 = [x[4] for x in Zürich_vp]
tmp2 = [x[4] for x in Zürich_fn]
tmp3 = [x[4] for x in Zürich_fp]
a,b,c = len(tmp1),len(tmp2),len(tmp3)
if a<b:
    for x in range(b-a):
        tmp1.append('')
else:
    for x in range(a-b):
        tmp2.append("")
    for x in range(a-c):
        tmp3.append('')
    

l1 = pd.DataFrame({"Vrai Postif":tmp1,"Faux positif":tmp3,"Faux Negatif":tmp2},index = [x for x in range(1,max(a,b)+1)])
with open("résultat/Model with train + Spacy Model/Zürich.html","w",encoding='utf-8') as f:
    f.write(html_string.format(table=l1.to_html()))

# %%
import nltk
import sklearn_crfsuite

from copy import deepcopy
from collections import defaultdict

from sklearn_crfsuite import metrics

import NER_Evaluation 
from NER_Evaluation import ner_evaluation

# %%
result2[1][0]
# Out:
# ['Condeer', 1, 8, 'LOC', '(Condeer.] Petersburg den 18. Dec.']

# %%
correction[1][0]
# Out:
# ['Petersburg',
#  11,
#  21,
#  'LOC',
#  '(Condeer.] Petersburg den 18. Dec. Se.russisch- kaiserl.']

# %%
from spacy import displacy

corpus = result2[1][0]
doc = SM_plus_Train_DATA_Model("Rußland. (Condeer.] Petersburg den 18")
displacy.serve(doc,style = "ent")
# Out:
# /Users/zijian/anaconda3/lib/python3.7/runpy.py:193: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   "__main__", mod_spec)
# <!DOCTYPE html>
# <html lang="de">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Rußland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Condeer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .]
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Petersburg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  den 18</div>
# </figure>
# </body>
# </html>
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %%
doc = SM_plus_Train_DATA_Model("sagt man, daß die Universität Zürich an")
displacy.serve(doc,style = "ent")
# Out:
# /Users/zijian/anaconda3/lib/python3.7/runpy.py:193: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   "__main__", mod_spec)
# <!DOCTYPE html>
# <html lang="de">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">sagt man, daß die
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Universität
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Zürich an</div>
# </figure>
# </body>
# </html>
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.
